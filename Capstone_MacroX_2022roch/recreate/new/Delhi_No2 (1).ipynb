# %%
import pandas as pd

data = pd.read_csv('Delhi_NO2.txt')

# %%
import numpy as np

# %%
df = data.drop(columns= 'date')
df
# Out:
#        open_NO2      sate_NO2  Alipur, Delhi - DPCC  \
# 0     92.707500  9.615744e+15                 48.35
# 1     85.681667  1.381297e+16                 47.06
# 2     63.533750  9.999100e+15                 33.04
# 3     55.179583  8.749730e+15                 29.30
# 4     73.030833  7.059130e+15                 22.62
# ..          ...           ...                   ...
# 398   96.963333  6.381238e+15                 23.85
# 399  101.418750  1.327145e+16                 31.94
# 400   76.913750  1.140000e+16                 34.24
# 401   89.023750  8.085128e+15                 38.04
# 402   79.112500  1.370000e+16                 42.65
#
#      Anand Vihar, Delhi - DPCC  Ashok Vihar, Delhi - DPCC  \
# 0                        73.67                      58.19
# 1                        87.96                      44.84
# 2                        43.54                      36.85
# 3                        78.91                      13.32
# 4                        38.28                      15.85
# ..                         ...                        ...
# 398                      61.91                      31.84
# 399                      76.38                      53.99
# 400                      75.54                      29.85
# 401                      82.37                      43.75
# 402                      93.98                      49.42
#
#      Aya Nagar, Delhi - IMD  Bawana, Delhi - DPCC  \
# 0                      7.14                 53.20
# 1                      3.49                 38.10
# 2                     20.88                 30.54
# 3                     13.05                 15.47
# 4                     13.12                 20.51
# ..                      ...                   ...
# 398                   21.79                 13.82
# 399                   21.95                 21.59
# 400                   18.56                 15.90
# 401                   25.14                 18.49
# 402                   22.63                 19.89
#
#      Burari Crossing, Delhi - IMD  Chandni Chowk, Delhi - IITM  \
# 0                       66.583333                        38.72
# 1                       67.341667                        56.06
# 2                       29.103333                        48.98
# 3                       19.021667                        19.97
# 4                       14.840000                        19.55
# ..                            ...                          ...
# 398                     35.228333                       134.50
# 399                     42.303333                       167.30
# 400                     39.063333                       238.93
# 401                     41.561667                       218.09
# 402                     47.221667                       209.76
#
#      CRRI Mathura Road, Delhi - IMD  ...  Pusa, Delhi - DPCC  \
# 0                            151.27  ...             73.6600
# 1                            100.49  ...             83.6700
# 2                             23.37  ...             54.6800
# 3                             15.98  ...             18.6275
# 4                              9.14  ...             20.4100
# ..                              ...  ...                 ...
# 398                           17.68  ...             56.5200
# 399                           19.42  ...             73.3500
# 400                           19.35  ...             66.6500
# 401                           19.69  ...             63.9200
# 402                           21.40  ...             74.6700
#
#      Pusa, Delhi - IMD  R K Puram, Delhi - DPCC  Rohini, Delhi - DPCC  \
# 0                63.75                    65.72                 31.10
# 1                14.00                    67.21                 23.60
# 2                17.16                    37.17                 28.57
# 3                13.37                    16.01                  7.82
# 4                15.34                    22.86                  8.19
# ..                 ...                      ...                   ...
# 398              48.22                    44.33                 27.44
# 399              44.55                    53.78                 40.23
# 400              16.78                    44.74                 24.62
# 401              15.06                    53.85                 27.62
# 402              19.24                    56.59                 28.85
#
#      Shadipur, Delhi - CPCB  Sirifort, Delhi - CPCB  \
# 0                     83.52                  89.030
# 1                     81.63                  59.360
# 2                     37.39                  46.570
# 3                     13.37                  12.950
# 4                     15.34                  25.790
# ..                      ...                     ...
# 398                   25.85                  43.100
# 399                   35.11                  50.806
# 400                   24.79                  41.064
# 401                   36.43                  39.336
# 402                   37.05                  43.138
#
#      Sonia Vihar, Delhi - DPCC  Sri Aurobindo Marg, Delhi - DPCC  \
# 0                        49.95                             31.79
# 1                        47.72                             37.36
# 2                        40.94                             22.84
# 3                        17.22                              3.38
# 4                        11.71                             16.59
# ..                         ...                               ...
# 398                      30.84                             23.96
# 399                      52.13                             32.75
# 400                      36.73                             22.75
# 401                      41.05                             34.97
# 402                      42.29                             36.57
#
#      Vivek Vihar, Delhi - DPCC  Wazirpur, Delhi - DPCC
# 0                        20.27                   18.76
# 1                        62.97                   64.11
# 2                        56.77                   39.66
# 3                        22.63                   32.31
# 4                        23.31                   25.62
# ..                         ...                     ...
# 398                      25.18                   34.51
# 399                      31.59                   39.10
# 400                      29.13                   34.41
# 401                      31.59                   43.85
# 402                      31.94                   44.27
#
# [403 rows x 42 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df)
df = pd.DataFrame(scaler.transform(df), index=df.index, columns=df.columns)
df
# Out:
#      open_NO2  sate_NO2  Alipur, Delhi - DPCC  Anand Vihar, Delhi - DPCC  \
# 0    0.346590  0.190428              0.510417                   0.298884
# 1    0.314144  0.345698              0.494737                   0.360963
# 2    0.211863  0.204610              0.324314                   0.167992
# 3    0.173282  0.158392              0.278852                   0.321647
# 4    0.255721  0.095851              0.197652                   0.145141
# ..        ...       ...                   ...                        ...
# 398  0.366244  0.070773              0.212603                   0.247795
# 399  0.386819  0.325665              0.310943                   0.310656
# 400  0.273653  0.256434              0.338901                   0.307007
# 401  0.329578  0.133806              0.385092                   0.336678
# 402  0.283807  0.341519              0.441130                   0.387115
#
#      Ashok Vihar, Delhi - DPCC  Aya Nagar, Delhi - IMD  Bawana, Delhi - DPCC  \
# 0                     0.271057                0.031742              0.616965
# 1                     0.193455                0.002559              0.435540
# 2                     0.147009                0.141601              0.344707
# 3                     0.010231                0.078996              0.163643
# 4                     0.024938                0.079555              0.224198
# ..                         ...                     ...                   ...
# 398                   0.117886                0.148877              0.143818
# 399                   0.246643                0.150156              0.237174
# 400                   0.106319                0.123051              0.168809
# 401                   0.187119                0.175662              0.199928
# 402                   0.220078                0.155593              0.216749
#
#      Burari Crossing, Delhi - IMD  Chandni Chowk, Delhi - IITM  \
# 0                        0.721059                     0.155496
# 1                        0.730655                     0.228408
# 2                        0.246765                     0.198638
# 3                        0.119185                     0.076655
# 4                        0.066268                     0.074889
# ..                            ...                          ...
# 398                      0.324274                     0.558237
# 399                      0.413805                     0.696157
# 400                      0.372804                     0.997351
# 401                      0.404420                     0.909722
# 402                      0.476045                     0.874695
#
#      CRRI Mathura Road, Delhi - IMD  ...  Pusa, Delhi - DPCC  \
# 0                          0.843647  ...            0.439759
# 1                          0.555354  ...            0.508283
# 2                          0.117520  ...            0.309830
# 3                          0.075565  ...            0.063031
# 4                          0.036732  ...            0.075233
# ..                              ...  ...                 ...
# 398                        0.085216  ...            0.322426
# 399                        0.095095  ...            0.437637
# 400                        0.094697  ...            0.391772
# 401                        0.096628  ...            0.373083
# 402                        0.106336  ...            0.446673
#
#      Pusa, Delhi - IMD  R K Puram, Delhi - DPCC  Rohini, Delhi - DPCC  \
# 0             0.247768                 0.639871              0.417306
# 1             0.048633                 0.654881              0.297345
# 2             0.061282                 0.352272              0.376839
# 3             0.046111                 0.139116              0.044946
# 4             0.053997                 0.208119              0.050864
# ..                 ...                      ...                   ...
# 398           0.185606                 0.424398              0.358765
# 399           0.170916                 0.519593              0.563340
# 400           0.059761                 0.428528              0.313660
# 401           0.052876                 0.520298              0.361644
# 402           0.069607                 0.547900              0.381318
#
#      Shadipur, Delhi - CPCB  Sirifort, Delhi - CPCB  \
# 0                  0.448547                0.502281
# 1                  0.437558                0.333124
# 2                  0.180349                0.260205
# 3                  0.040698                0.068529
# 4                  0.052151                0.141733
# ..                      ...                     ...
# 398                0.113256                0.240422
# 399                0.167093                0.284356
# 400                0.107093                0.228814
# 401                0.174767                0.218962
# 402                0.178372                0.240639
#
#      Sonia Vihar, Delhi - DPCC  Sri Aurobindo Marg, Delhi - DPCC  \
# 0                     0.452171                          0.517204
# 1                     0.430753                          0.618605
# 2                     0.365636                          0.354269
# 3                     0.137822                          0.000000
# 4                     0.084902                          0.240488
# ..                         ...                               ...
# 398                   0.268632                          0.374659
# 399                   0.473108                          0.534681
# 400                   0.325202                          0.352631
# 401                   0.366692                          0.575096
# 402                   0.378602                          0.604224
#
#      Vivek Vihar, Delhi - DPCC  Wazirpur, Delhi - DPCC
# 0                     0.198853                0.089107
# 1                     0.628560                0.557357
# 2                     0.566167                0.304904
# 3                     0.222602                0.229014
# 4                     0.229446                0.159938
# ..                         ...                     ...
# 398                   0.248264                0.251729
# 399                   0.312770                0.299122
# 400                   0.288014                0.250697
# 401                   0.312770                0.348167
# 402                   0.316293                0.352504
#
# [403 rows x 42 columns]

# %%
ax = df.plot(linewidth=1, fontsize=12);
ax.set_xlabel('Date');
ax.legend(fontsize=2);

# %%
df
# Out:
#      open_NO2  sate_NO2  Alipur, Delhi - DPCC  Anand Vihar, Delhi - DPCC  \
# 0    0.346590  0.190428              0.510417                   0.298884
# 1    0.314144  0.345698              0.494737                   0.360963
# 2    0.211863  0.204610              0.324314                   0.167992
# 3    0.173282  0.158392              0.278852                   0.321647
# 4    0.255721  0.095851              0.197652                   0.145141
# ..        ...       ...                   ...                        ...
# 398  0.366244  0.070773              0.212603                   0.247795
# 399  0.386819  0.325665              0.310943                   0.310656
# 400  0.273653  0.256434              0.338901                   0.307007
# 401  0.329578  0.133806              0.385092                   0.336678
# 402  0.283807  0.341519              0.441130                   0.387115
#
#      Ashok Vihar, Delhi - DPCC  Aya Nagar, Delhi - IMD  Bawana, Delhi - DPCC  \
# 0                     0.271057                0.031742              0.616965
# 1                     0.193455                0.002559              0.435540
# 2                     0.147009                0.141601              0.344707
# 3                     0.010231                0.078996              0.163643
# 4                     0.024938                0.079555              0.224198
# ..                         ...                     ...                   ...
# 398                   0.117886                0.148877              0.143818
# 399                   0.246643                0.150156              0.237174
# 400                   0.106319                0.123051              0.168809
# 401                   0.187119                0.175662              0.199928
# 402                   0.220078                0.155593              0.216749
#
#      Burari Crossing, Delhi - IMD  Chandni Chowk, Delhi - IITM  \
# 0                        0.721059                     0.155496
# 1                        0.730655                     0.228408
# 2                        0.246765                     0.198638
# 3                        0.119185                     0.076655
# 4                        0.066268                     0.074889
# ..                            ...                          ...
# 398                      0.324274                     0.558237
# 399                      0.413805                     0.696157
# 400                      0.372804                     0.997351
# 401                      0.404420                     0.909722
# 402                      0.476045                     0.874695
#
#      CRRI Mathura Road, Delhi - IMD  ...  Pusa, Delhi - DPCC  \
# 0                          0.843647  ...            0.439759
# 1                          0.555354  ...            0.508283
# 2                          0.117520  ...            0.309830
# 3                          0.075565  ...            0.063031
# 4                          0.036732  ...            0.075233
# ..                              ...  ...                 ...
# 398                        0.085216  ...            0.322426
# 399                        0.095095  ...            0.437637
# 400                        0.094697  ...            0.391772
# 401                        0.096628  ...            0.373083
# 402                        0.106336  ...            0.446673
#
#      Pusa, Delhi - IMD  R K Puram, Delhi - DPCC  Rohini, Delhi - DPCC  \
# 0             0.247768                 0.639871              0.417306
# 1             0.048633                 0.654881              0.297345
# 2             0.061282                 0.352272              0.376839
# 3             0.046111                 0.139116              0.044946
# 4             0.053997                 0.208119              0.050864
# ..                 ...                      ...                   ...
# 398           0.185606                 0.424398              0.358765
# 399           0.170916                 0.519593              0.563340
# 400           0.059761                 0.428528              0.313660
# 401           0.052876                 0.520298              0.361644
# 402           0.069607                 0.547900              0.381318
#
#      Shadipur, Delhi - CPCB  Sirifort, Delhi - CPCB  \
# 0                  0.448547                0.502281
# 1                  0.437558                0.333124
# 2                  0.180349                0.260205
# 3                  0.040698                0.068529
# 4                  0.052151                0.141733
# ..                      ...                     ...
# 398                0.113256                0.240422
# 399                0.167093                0.284356
# 400                0.107093                0.228814
# 401                0.174767                0.218962
# 402                0.178372                0.240639
#
#      Sonia Vihar, Delhi - DPCC  Sri Aurobindo Marg, Delhi - DPCC  \
# 0                     0.452171                          0.517204
# 1                     0.430753                          0.618605
# 2                     0.365636                          0.354269
# 3                     0.137822                          0.000000
# 4                     0.084902                          0.240488
# ..                         ...                               ...
# 398                   0.268632                          0.374659
# 399                   0.473108                          0.534681
# 400                   0.325202                          0.352631
# 401                   0.366692                          0.575096
# 402                   0.378602                          0.604224
#
#      Vivek Vihar, Delhi - DPCC  Wazirpur, Delhi - DPCC
# 0                     0.198853                0.089107
# 1                     0.628560                0.557357
# 2                     0.566167                0.304904
# 3                     0.222602                0.229014
# 4                     0.229446                0.159938
# ..                         ...                     ...
# 398                   0.248264                0.251729
# 399                   0.312770                0.299122
# 400                   0.288014                0.250697
# 401                   0.312770                0.348167
# 402                   0.316293                0.352504
#
# [403 rows x 42 columns]

# %%
y = df['open_NO2']
x = df.drop(columns =["open_NO2"])

# %%
df.describe()
# Out:
#          open_NO2    sate_NO2  Alipur, Delhi - DPCC  \
# count  403.000000  403.000000            403.000000
# mean     0.235031    0.147908              0.264595
# std      0.148470    0.105160              0.169465
# min      0.000000    0.000000              0.000000
# 25%      0.129854    0.083906              0.128121
# 50%      0.199265    0.120945              0.240561
# 75%      0.310534    0.180051              0.378164
# max      1.000000    1.000000              1.000000
#
#        Anand Vihar, Delhi - DPCC  Ashok Vihar, Delhi - DPCC  \
# count                 403.000000                 403.000000
# mean                    0.302311                   0.196480
# std                     0.167582                   0.147953
# min                     0.000000                   0.000000
# 25%                     0.167036                   0.081585
# 50%                     0.280073                   0.161832
# 75%                     0.417894                   0.285183
# max                     1.000000                   1.000000
#
#        Aya Nagar, Delhi - IMD  Bawana, Delhi - DPCC  \
# count              403.000000            403.000000
# mean                 0.097783              0.192855
# std                  0.083452              0.162853
# min                  0.000000              0.000000
# 25%                  0.036180              0.067764
# 50%                  0.079635              0.143218
# 75%                  0.142480              0.269254
# max                  1.000000              1.000000
#
#        Burari Crossing, Delhi - IMD  Chandni Chowk, Delhi - IITM  \
# count                    403.000000                   403.000000
# mean                       0.381627                     0.133078
# std                        0.229349                     0.143273
# min                        0.000000                     0.000000
# 25%                        0.170616                     0.060193
# 50%                        0.399485                     0.092717
# 75%                        0.559955                     0.154697
# max                        1.000000                     1.000000
#
#        CRRI Mathura Road, Delhi - IMD  ...  Pusa, Delhi - DPCC  \
# count                      403.000000  ...          403.000000
# mean                         0.257085  ...            0.272789
# std                          0.322628  ...            0.167881
# min                          0.000000  ...            0.000000
# 25%                          0.061769  ...            0.137801
# 50%                          0.105144  ...            0.276698
# 75%                          0.276627  ...            0.398241
# max                          1.000000  ...            1.000000
#
#        Pusa, Delhi - IMD  R K Puram, Delhi - DPCC  Rohini, Delhi - DPCC  \
# count         403.000000               403.000000            403.000000
# mean            0.175228                 0.380036              0.280966
# std             0.150469                 0.222330              0.190025
# min             0.000000                 0.000000              0.000000
# 25%             0.065965                 0.220308              0.135637
# 50%             0.122603                 0.401733              0.234325
# 75%             0.245567                 0.541352              0.381238
# max             1.000000                 1.000000              1.000000
#
#        Shadipur, Delhi - CPCB  Sirifort, Delhi - CPCB  \
# count              403.000000              403.000000
# mean                 0.248605                0.184732
# std                  0.185845                0.161614
# min                  0.000000                0.000000
# 25%                  0.095727                0.094236
# 50%                  0.213605                0.132269
# 75%                  0.361599                0.219173
# max                  1.000000                1.000000
#
#        Sonia Vihar, Delhi - DPCC  Sri Aurobindo Marg, Delhi - DPCC  \
# count                 403.000000                        403.000000
# mean                    0.349393                          0.418766
# std                     0.184849                          0.167176
# min                     0.000000                          0.000000
# 25%                     0.198521                          0.284544
# 50%                     0.329812                          0.411979
# 75%                     0.475989                          0.522756
# max                     1.000000                          1.000000
#
#        Vivek Vihar, Delhi - DPCC  Wazirpur, Delhi - DPCC
# count                 403.000000              403.000000
# mean                    0.301947                0.316178
# std                     0.164358                0.239292
# min                     0.000000                0.000000
# 25%                     0.186475                0.113010
# 50%                     0.259636                0.258131
# 75%                     0.387793                0.493340
# max                     1.000000                1.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# # Normal OLS

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression


cv = KFold(n_splits=10, random_state=1, shuffle=True)
model = LinearRegression().fit(x,y)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 5151550.366006491

# %%
scores = cross_val_score(model, x, y, scoring='r2',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 4.331204954851818e+17

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_predict


predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # LASSO

# %%
from sklearn import linear_model
import warnings
warnings.filterwarnings("ignore")
model = linear_model.Lasso(alpha=0.1)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.11518637107921899

# %%
scores = cross_val_score(model, x, y, scoring='r2',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.02567943104080661

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # Ridge

# %%
from sklearn.linear_model import Ridge
model = Ridge(alpha=0.1)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.08270951989422651

# %%
scores = cross_val_score(model, x, y, scoring='r2',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.4080307383213716

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # Elastic Net

# %%
from sklearn.linear_model import ElasticNet
model = ElasticNet(random_state=0)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.11518637107921899

# %%
scores = cross_val_score(model, x, y, scoring='r2',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.02567943104080661

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # Decision tree

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.10544118987116564

# %%
scores = cross_val_score(model, x, y, scoring='r2',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.18806505982233265

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %%
regr = tree.DecisionTreeRegressor()
model = regr.fit(x, y)
text_representation = tree.export_text(regr)
print(text_representation)
# Out:
# |--- feature_34 <= 0.40
# |   |--- feature_4 <= 0.09
# |   |   |--- feature_33 <= 0.38
# |   |   |   |--- feature_39 <= 0.04
# |   |   |   |   |--- feature_4 <= 0.03
# |   |   |   |   |   |--- feature_37 <= 0.00
# |   |   |   |   |   |   |--- feature_1 <= 0.18
# |   |   |   |   |   |   |   |--- value: [0.21]
# |   |   |   |   |   |   |--- feature_1 >  0.18
# |   |   |   |   |   |   |   |--- value: [0.20]
# |   |   |   |   |   |--- feature_37 >  0.00
# |   |   |   |   |   |   |--- value: [0.30]
# |   |   |   |   |--- feature_4 >  0.03
# |   |   |   |   |   |--- feature_30 <= 0.11
# |   |   |   |   |   |   |--- value: [0.47]
# |   |   |   |   |   |--- feature_30 >  0.11
# |   |   |   |   |   |   |--- value: [0.41]
# |   |   |   |--- feature_39 >  0.04
# |   |   |   |   |--- feature_27 <= 0.21
# |   |   |   |   |   |--- feature_38 <= 0.23
# |   |   |   |   |   |   |--- feature_14 <= 0.12
# |   |   |   |   |   |   |   |--- feature_31 <= 0.06
# |   |   |   |   |   |   |   |   |--- feature_38 <= 0.21
# |   |   |   |   |   |   |   |   |   |--- feature_23 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.05]
# |   |   |   |   |   |   |   |   |   |--- feature_23 >  0.08
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 >  0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |   |   |--- feature_38 >  0.21
# |   |   |   |   |   |   |   |   |   |--- feature_31 <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.10]
# |   |   |   |   |   |   |   |   |   |--- feature_31 >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |   |   |--- feature_31 >  0.06
# |   |   |   |   |   |   |   |   |--- feature_9 <= 0.08
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 0.52
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  0.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  0.52
# |   |   |   |   |   |   |   |   |   |   |--- feature_28 <= 0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |   |   |   |   |--- feature_28 >  0.03
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.21]
# |   |   |   |   |   |   |   |   |--- feature_9 >  0.08
# |   |   |   |   |   |   |   |   |   |--- feature_21 <= 0.32
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |   |   |--- feature_21 >  0.32
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 >  0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |--- feature_14 >  0.12
# |   |   |   |   |   |   |   |--- feature_40 <= 0.13
# |   |   |   |   |   |   |   |   |--- feature_31 <= 0.34
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- feature_31 <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_31 >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_31 >  0.34
# |   |   |   |   |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |   |   |   |--- feature_40 >  0.13
# |   |   |   |   |   |   |   |   |--- feature_28 <= 0.11
# |   |   |   |   |   |   |   |   |   |--- value: [0.06]
# |   |   |   |   |   |   |   |   |--- feature_28 >  0.11
# |   |   |   |   |   |   |   |   |   |--- feature_23 <= 0.07
# |   |   |   |   |   |   |   |   |   |   |--- feature_35 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_35 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |   |   |--- feature_23 >  0.07
# |   |   |   |   |   |   |   |   |   |   |--- feature_35 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |   |   |   |   |--- feature_35 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |--- feature_38 >  0.23
# |   |   |   |   |   |   |--- feature_10 <= 0.06
# |   |   |   |   |   |   |   |--- feature_15 <= 0.15
# |   |   |   |   |   |   |   |   |--- feature_28 <= 0.14
# |   |   |   |   |   |   |   |   |   |--- feature_22 <= 0.12
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |   |   |   |   |--- feature_22 >  0.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |   |   |   |--- feature_28 >  0.14
# |   |   |   |   |   |   |   |   |   |--- feature_35 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.21]
# |   |   |   |   |   |   |   |   |   |--- feature_35 >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.21]
# |   |   |   |   |   |   |   |--- feature_15 >  0.15
# |   |   |   |   |   |   |   |   |--- feature_37 <= 0.22
# |   |   |   |   |   |   |   |   |   |--- feature_36 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 >  0.16
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.29]
# |   |   |   |   |   |   |   |   |   |--- feature_36 >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 >  0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |   |   |   |   |   |--- feature_37 >  0.22
# |   |   |   |   |   |   |   |   |   |--- feature_23 <= 0.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.18]
# |   |   |   |   |   |   |   |   |   |--- feature_23 >  0.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.15]
# |   |   |   |   |   |   |--- feature_10 >  0.06
# |   |   |   |   |   |   |   |--- feature_35 <= 0.02
# |   |   |   |   |   |   |   |   |--- feature_12 <= 0.29
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- feature_20 <= 0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |   |   |   |   |--- feature_20 >  0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |   |   |--- feature_12 >  0.29
# |   |   |   |   |   |   |   |   |   |--- value: [0.37]
# |   |   |   |   |   |   |   |--- feature_35 >  0.02
# |   |   |   |   |   |   |   |   |--- feature_18 <= 0.28
# |   |   |   |   |   |   |   |   |   |--- feature_30 <= 0.06
# |   |   |   |   |   |   |   |   |   |   |--- feature_20 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_20 >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_30 >  0.06
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 <= 0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 >  0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.27]
# |   |   |   |   |   |   |   |   |--- feature_18 >  0.28
# |   |   |   |   |   |   |   |   |   |--- feature_14 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |--- feature_29 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_29 >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_14 >  0.10
# |   |   |   |   |   |   |   |   |   |   |--- feature_23 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_23 >  0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |--- feature_27 >  0.21
# |   |   |   |   |   |--- feature_26 <= 0.08
# |   |   |   |   |   |   |--- feature_35 <= 0.05
# |   |   |   |   |   |   |   |--- feature_6 <= 0.07
# |   |   |   |   |   |   |   |   |--- feature_31 <= 0.31
# |   |   |   |   |   |   |   |   |   |--- value: [0.35]
# |   |   |   |   |   |   |   |   |--- feature_31 >  0.31
# |   |   |   |   |   |   |   |   |   |--- value: [0.33]
# |   |   |   |   |   |   |   |--- feature_6 >  0.07
# |   |   |   |   |   |   |   |   |--- value: [0.30]
# |   |   |   |   |   |   |--- feature_35 >  0.05
# |   |   |   |   |   |   |   |--- feature_7 <= 0.07
# |   |   |   |   |   |   |   |   |--- feature_21 <= 0.37
# |   |   |   |   |   |   |   |   |   |--- value: [0.29]
# |   |   |   |   |   |   |   |   |--- feature_21 >  0.37
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.27]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.26]
# |   |   |   |   |   |   |   |--- feature_7 >  0.07
# |   |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |   |--- feature_26 >  0.08
# |   |   |   |   |   |   |--- feature_26 <= 0.32
# |   |   |   |   |   |   |   |--- feature_11 <= 0.13
# |   |   |   |   |   |   |   |   |--- value: [0.06]
# |   |   |   |   |   |   |   |--- feature_11 >  0.13
# |   |   |   |   |   |   |   |   |--- feature_18 <= 0.51
# |   |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |   |   |   |--- feature_18 >  0.51
# |   |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |   |--- feature_26 >  0.32
# |   |   |   |   |   |   |   |--- feature_13 <= 0.16
# |   |   |   |   |   |   |   |   |--- value: [0.20]
# |   |   |   |   |   |   |   |--- feature_13 >  0.16
# |   |   |   |   |   |   |   |   |--- value: [0.20]
# |   |   |--- feature_33 >  0.38
# |   |   |   |--- feature_30 <= 0.20
# |   |   |   |   |--- feature_23 <= 0.14
# |   |   |   |   |   |--- feature_19 <= 0.28
# |   |   |   |   |   |   |--- feature_30 <= 0.06
# |   |   |   |   |   |   |   |--- value: [0.37]
# |   |   |   |   |   |   |--- feature_30 >  0.06
# |   |   |   |   |   |   |   |--- feature_13 <= 0.10
# |   |   |   |   |   |   |   |   |--- feature_18 <= 0.15
# |   |   |   |   |   |   |   |   |   |--- value: [0.42]
# |   |   |   |   |   |   |   |   |--- feature_18 >  0.15
# |   |   |   |   |   |   |   |   |   |--- value: [0.41]
# |   |   |   |   |   |   |   |--- feature_13 >  0.10
# |   |   |   |   |   |   |   |   |--- value: [0.44]
# |   |   |   |   |   |--- feature_19 >  0.28
# |   |   |   |   |   |   |--- feature_15 <= 0.27
# |   |   |   |   |   |   |   |--- value: [0.68]
# |   |   |   |   |   |   |--- feature_15 >  0.27
# |   |   |   |   |   |   |   |--- value: [0.61]
# |   |   |   |   |--- feature_23 >  0.14
# |   |   |   |   |   |--- feature_6 <= 0.59
# |   |   |   |   |   |   |--- value: [0.51]
# |   |   |   |   |   |--- feature_6 >  0.59
# |   |   |   |   |   |   |--- feature_23 <= 0.14
# |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |   |--- feature_23 >  0.14
# |   |   |   |   |   |   |   |--- feature_22 <= 0.12
# |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |   |--- feature_22 >  0.12
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.12
# |   |   |   |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.12
# |   |   |   |   |   |   |   |   |   |--- feature_27 <= 0.22
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |   |   |   |--- feature_27 >  0.22
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.18]
# |   |   |   |--- feature_30 >  0.20
# |   |   |   |   |--- feature_13 <= 0.14
# |   |   |   |   |   |--- feature_30 <= 0.38
# |   |   |   |   |   |   |--- feature_21 <= 0.37
# |   |   |   |   |   |   |   |--- feature_36 <= 0.13
# |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |   |   |--- feature_36 >  0.13
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.12
# |   |   |   |   |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.12
# |   |   |   |   |   |   |   |   |   |--- value: [0.05]
# |   |   |   |   |   |   |--- feature_21 >  0.37
# |   |   |   |   |   |   |   |--- feature_40 <= 0.41
# |   |   |   |   |   |   |   |   |--- feature_38 <= 0.43
# |   |   |   |   |   |   |   |   |   |--- feature_21 <= 0.48
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.20]
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_21 >  0.48
# |   |   |   |   |   |   |   |   |   |   |--- feature_26 <= 0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |   |   |   |--- feature_26 >  0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |--- feature_38 >  0.43
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.33
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 <= 0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 >  0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.33
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |   |   |--- feature_40 >  0.41
# |   |   |   |   |   |   |   |   |--- feature_22 <= 0.33
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.33
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.33
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |   |--- feature_22 >  0.33
# |   |   |   |   |   |   |   |   |   |--- feature_26 <= 0.32
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.10]
# |   |   |   |   |   |   |   |   |   |--- feature_26 >  0.32
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |--- feature_30 >  0.38
# |   |   |   |   |   |   |--- feature_24 <= 0.35
# |   |   |   |   |   |   |   |--- value: [0.29]
# |   |   |   |   |   |   |--- feature_24 >  0.35
# |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |--- feature_13 >  0.14
# |   |   |   |   |   |--- feature_33 <= 0.50
# |   |   |   |   |   |   |--- feature_33 <= 0.41
# |   |   |   |   |   |   |   |--- feature_6 <= 0.40
# |   |   |   |   |   |   |   |   |--- value: [0.27]
# |   |   |   |   |   |   |   |--- feature_6 >  0.40
# |   |   |   |   |   |   |   |   |--- value: [0.32]
# |   |   |   |   |   |   |--- feature_33 >  0.41
# |   |   |   |   |   |   |   |--- feature_13 <= 0.24
# |   |   |   |   |   |   |   |   |--- feature_14 <= 0.39
# |   |   |   |   |   |   |   |   |   |--- feature_34 <= 0.19
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.05]
# |   |   |   |   |   |   |   |   |   |--- feature_34 >  0.19
# |   |   |   |   |   |   |   |   |   |   |--- feature_34 <= 0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |   |   |   |   |   |--- feature_34 >  0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |   |   |   |--- feature_14 >  0.39
# |   |   |   |   |   |   |   |   |   |--- value: [0.16]
# |   |   |   |   |   |   |   |--- feature_13 >  0.24
# |   |   |   |   |   |   |   |   |--- feature_33 <= 0.48
# |   |   |   |   |   |   |   |   |   |--- feature_25 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |   |   |   |--- feature_25 >  0.16
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |   |   |   |   |--- feature_33 >  0.48
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= 0.26
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.20]
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  0.26
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.21]
# |   |   |   |   |   |--- feature_33 >  0.50
# |   |   |   |   |   |   |--- feature_2 <= 0.53
# |   |   |   |   |   |   |   |--- feature_0 <= 0.14
# |   |   |   |   |   |   |   |   |--- feature_11 <= 0.21
# |   |   |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |   |   |   |   |--- feature_11 >  0.21
# |   |   |   |   |   |   |   |   |   |--- feature_26 <= 0.37
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.25]
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  0.27
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.26]
# |   |   |   |   |   |   |   |   |   |--- feature_26 >  0.37
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |   |   |   |   |--- feature_0 >  0.14
# |   |   |   |   |   |   |   |   |--- feature_14 <= 0.22
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 0.24
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.30]
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  0.24
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |   |   |   |   |   |--- feature_14 >  0.22
# |   |   |   |   |   |   |   |   |   |--- feature_35 <= 0.45
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |   |   |   |   |--- feature_35 >  0.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_34 <= 0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.34]
# |   |   |   |   |   |   |   |   |   |   |--- feature_34 >  0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.33]
# |   |   |   |   |   |   |--- feature_2 >  0.53
# |   |   |   |   |   |   |   |--- feature_16 <= 0.27
# |   |   |   |   |   |   |   |   |--- value: [0.20]
# |   |   |   |   |   |   |   |--- feature_16 >  0.27
# |   |   |   |   |   |   |   |   |--- value: [0.14]
# |   |--- feature_4 >  0.09
# |   |   |--- feature_17 <= 0.17
# |   |   |   |--- feature_0 <= 0.15
# |   |   |   |   |--- feature_13 <= 0.04
# |   |   |   |   |   |--- feature_0 <= 0.11
# |   |   |   |   |   |   |--- feature_36 <= 0.17
# |   |   |   |   |   |   |   |--- value: [0.27]
# |   |   |   |   |   |   |--- feature_36 >  0.17
# |   |   |   |   |   |   |   |--- value: [0.26]
# |   |   |   |   |   |--- feature_0 >  0.11
# |   |   |   |   |   |   |--- feature_2 <= 0.25
# |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |   |   |--- feature_2 >  0.25
# |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |   |--- feature_13 >  0.04
# |   |   |   |   |   |--- feature_9 <= 0.09
# |   |   |   |   |   |   |--- feature_38 <= 0.35
# |   |   |   |   |   |   |   |--- feature_28 <= 0.11
# |   |   |   |   |   |   |   |   |--- value: [0.39]
# |   |   |   |   |   |   |   |--- feature_28 >  0.11
# |   |   |   |   |   |   |   |   |--- value: [0.39]
# |   |   |   |   |   |   |--- feature_38 >  0.35
# |   |   |   |   |   |   |   |--- value: [0.37]
# |   |   |   |   |   |--- feature_9 >  0.09
# |   |   |   |   |   |   |--- feature_21 <= 0.35
# |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |   |--- feature_21 >  0.35
# |   |   |   |   |   |   |   |--- value: [0.35]
# |   |   |   |--- feature_0 >  0.15
# |   |   |   |   |--- feature_38 <= 0.23
# |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |--- feature_38 >  0.23
# |   |   |   |   |   |--- feature_28 <= 0.18
# |   |   |   |   |   |   |--- value: [0.71]
# |   |   |   |   |   |--- feature_28 >  0.18
# |   |   |   |   |   |   |--- value: [0.64]
# |   |   |--- feature_17 >  0.17
# |   |   |   |--- feature_7 <= 0.26
# |   |   |   |   |--- feature_5 <= 0.19
# |   |   |   |   |   |--- feature_38 <= 0.36
# |   |   |   |   |   |   |--- feature_11 <= 0.17
# |   |   |   |   |   |   |   |--- feature_6 <= 0.13
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.07
# |   |   |   |   |   |   |   |   |   |--- value: [0.26]
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.07
# |   |   |   |   |   |   |   |   |   |--- value: [0.26]
# |   |   |   |   |   |   |   |--- feature_6 >  0.13
# |   |   |   |   |   |   |   |   |--- feature_3 <= 0.05
# |   |   |   |   |   |   |   |   |   |--- value: [0.25]
# |   |   |   |   |   |   |   |   |--- feature_3 >  0.05
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.31
# |   |   |   |   |   |   |   |   |   |   |--- feature_23 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |   |   |   |   |--- feature_23 >  0.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.31
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.21]
# |   |   |   |   |   |   |--- feature_11 >  0.17
# |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |--- feature_38 >  0.36
# |   |   |   |   |   |   |--- feature_20 <= 0.29
# |   |   |   |   |   |   |   |--- feature_15 <= 0.15
# |   |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |   |   |   |   |--- feature_15 >  0.15
# |   |   |   |   |   |   |   |   |--- feature_38 <= 0.49
# |   |   |   |   |   |   |   |   |   |--- feature_25 <= 0.28
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 <= 0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 >  0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |   |   |   |--- feature_25 >  0.28
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.18]
# |   |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_38 >  0.49
# |   |   |   |   |   |   |   |   |   |--- feature_31 <= 0.45
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |   |   |   |   |   |--- feature_31 >  0.45
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 <= 0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 >  0.28
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |--- feature_20 >  0.29
# |   |   |   |   |   |   |   |--- feature_11 <= 0.26
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.36
# |   |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.36
# |   |   |   |   |   |   |   |   |   |--- feature_37 <= 0.48
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.21]
# |   |   |   |   |   |   |   |   |   |--- feature_37 >  0.48
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.20]
# |   |   |   |   |   |   |   |--- feature_11 >  0.26
# |   |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |   |--- feature_5 >  0.19
# |   |   |   |   |   |--- feature_9 <= 0.29
# |   |   |   |   |   |   |--- feature_29 <= 0.18
# |   |   |   |   |   |   |   |--- feature_22 <= 0.29
# |   |   |   |   |   |   |   |   |--- feature_33 <= 0.40
# |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.07
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.07
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |   |   |   |   |   |--- feature_33 >  0.40
# |   |   |   |   |   |   |   |   |   |--- feature_38 <= 0.36
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.27]
# |   |   |   |   |   |   |   |   |   |--- feature_38 >  0.36
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 <= 0.52
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.25]
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 >  0.52
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.25]
# |   |   |   |   |   |   |   |--- feature_22 >  0.29
# |   |   |   |   |   |   |   |   |--- value: [0.21]
# |   |   |   |   |   |   |--- feature_29 >  0.18
# |   |   |   |   |   |   |   |--- feature_3 <= 0.24
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.09
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.15
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.15
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 <= 0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.16]
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 >  0.37
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.16]
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.09
# |   |   |   |   |   |   |   |   |   |--- value: [0.15]
# |   |   |   |   |   |   |   |--- feature_3 >  0.24
# |   |   |   |   |   |   |   |   |--- feature_7 <= 0.11
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.34
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.29]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.34
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 <= 0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 >  0.35
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_7 >  0.11
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 <= 0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 >  0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.50
# |   |   |   |   |   |   |   |   |   |   |--- feature_34 <= 0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_34 >  0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |--- feature_9 >  0.29
# |   |   |   |   |   |   |--- feature_2 <= 0.44
# |   |   |   |   |   |   |   |--- feature_16 <= 0.45
# |   |   |   |   |   |   |   |   |--- value: [0.39]
# |   |   |   |   |   |   |   |--- feature_16 >  0.45
# |   |   |   |   |   |   |   |   |--- value: [0.43]
# |   |   |   |   |   |   |--- feature_2 >  0.44
# |   |   |   |   |   |   |   |--- feature_14 <= 0.86
# |   |   |   |   |   |   |   |   |--- feature_16 <= 0.31
# |   |   |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |   |   |   |--- feature_16 >  0.31
# |   |   |   |   |   |   |   |   |   |--- value: [0.35]
# |   |   |   |   |   |   |   |--- feature_14 >  0.86
# |   |   |   |   |   |   |   |   |--- value: [0.25]
# |   |   |   |--- feature_7 >  0.26
# |   |   |   |   |--- feature_0 <= 0.06
# |   |   |   |   |   |--- value: [0.16]
# |   |   |   |   |--- feature_0 >  0.06
# |   |   |   |   |   |--- feature_15 <= 0.52
# |   |   |   |   |   |   |--- feature_8 <= 0.09
# |   |   |   |   |   |   |   |--- feature_14 <= 0.31
# |   |   |   |   |   |   |   |   |--- value: [0.37]
# |   |   |   |   |   |   |   |--- feature_14 >  0.31
# |   |   |   |   |   |   |   |   |--- value: [0.39]
# |   |   |   |   |   |   |--- feature_8 >  0.09
# |   |   |   |   |   |   |   |--- feature_3 <= 0.31
# |   |   |   |   |   |   |   |   |--- feature_32 <= 0.06
# |   |   |   |   |   |   |   |   |   |--- value: [0.33]
# |   |   |   |   |   |   |   |   |--- feature_32 >  0.06
# |   |   |   |   |   |   |   |   |   |--- feature_23 <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 <= 0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 >  0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.26]
# |   |   |   |   |   |   |   |   |   |--- feature_23 >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- feature_23 <= 0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_23 >  0.25
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_3 >  0.31
# |   |   |   |   |   |   |   |   |--- feature_0 <= 0.12
# |   |   |   |   |   |   |   |   |   |--- value: [0.33]
# |   |   |   |   |   |   |   |   |--- feature_0 >  0.12
# |   |   |   |   |   |   |   |   |   |--- value: [0.37]
# |   |   |   |   |   |--- feature_15 >  0.52
# |   |   |   |   |   |   |--- value: [0.46]
# |--- feature_34 >  0.40
# |   |--- feature_25 <= 0.41
# |   |   |--- feature_11 <= 0.54
# |   |   |   |--- feature_1 <= 0.36
# |   |   |   |   |--- feature_39 <= 0.61
# |   |   |   |   |   |--- feature_27 <= 0.32
# |   |   |   |   |   |   |--- feature_35 <= 0.42
# |   |   |   |   |   |   |   |--- feature_8 <= 0.06
# |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |   |--- feature_8 >  0.06
# |   |   |   |   |   |   |   |   |--- feature_25 <= 0.38
# |   |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |   |   |--- feature_25 >  0.38
# |   |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |--- feature_35 >  0.42
# |   |   |   |   |   |   |   |--- feature_27 <= 0.17
# |   |   |   |   |   |   |   |   |--- value: [0.19]
# |   |   |   |   |   |   |   |--- feature_27 >  0.17
# |   |   |   |   |   |   |   |   |--- value: [0.20]
# |   |   |   |   |   |--- feature_27 >  0.32
# |   |   |   |   |   |   |--- feature_24 <= 0.32
# |   |   |   |   |   |   |   |--- value: [0.06]
# |   |   |   |   |   |   |--- feature_24 >  0.32
# |   |   |   |   |   |   |   |--- feature_18 <= 0.29
# |   |   |   |   |   |   |   |   |--- value: [0.16]
# |   |   |   |   |   |   |   |--- feature_18 >  0.29
# |   |   |   |   |   |   |   |   |--- feature_27 <= 0.52
# |   |   |   |   |   |   |   |   |   |--- feature_23 <= 0.29
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |   |   |   |   |--- feature_23 >  0.29
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |   |   |   |--- feature_27 >  0.52
# |   |   |   |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |--- feature_39 >  0.61
# |   |   |   |   |   |--- feature_25 <= 0.25
# |   |   |   |   |   |   |--- value: [0.20]
# |   |   |   |   |   |--- feature_25 >  0.25
# |   |   |   |   |   |   |--- feature_0 <= 0.14
# |   |   |   |   |   |   |   |--- value: [0.38]
# |   |   |   |   |   |   |--- feature_0 >  0.14
# |   |   |   |   |   |   |   |--- feature_23 <= 0.33
# |   |   |   |   |   |   |   |   |--- value: [0.30]
# |   |   |   |   |   |   |   |--- feature_23 >  0.33
# |   |   |   |   |   |   |   |   |--- value: [0.34]
# |   |   |   |--- feature_1 >  0.36
# |   |   |   |   |--- feature_38 <= 0.64
# |   |   |   |   |   |--- feature_21 <= 0.49
# |   |   |   |   |   |   |--- feature_23 <= 0.25
# |   |   |   |   |   |   |   |--- feature_32 <= 0.31
# |   |   |   |   |   |   |   |   |--- value: [0.48]
# |   |   |   |   |   |   |   |--- feature_32 >  0.31
# |   |   |   |   |   |   |   |   |--- value: [0.45]
# |   |   |   |   |   |   |--- feature_23 >  0.25
# |   |   |   |   |   |   |   |--- feature_10 <= 0.15
# |   |   |   |   |   |   |   |   |--- value: [0.35]
# |   |   |   |   |   |   |   |--- feature_10 >  0.15
# |   |   |   |   |   |   |   |   |--- feature_29 <= 0.51
# |   |   |   |   |   |   |   |   |   |--- value: [0.40]
# |   |   |   |   |   |   |   |   |--- feature_29 >  0.51
# |   |   |   |   |   |   |   |   |   |--- value: [0.42]
# |   |   |   |   |   |--- feature_21 >  0.49
# |   |   |   |   |   |   |--- feature_38 <= 0.54
# |   |   |   |   |   |   |   |--- feature_4 <= 0.08
# |   |   |   |   |   |   |   |   |--- feature_20 <= 0.31
# |   |   |   |   |   |   |   |   |   |--- value: [0.36]
# |   |   |   |   |   |   |   |   |--- feature_20 >  0.31
# |   |   |   |   |   |   |   |   |   |--- value: [0.33]
# |   |   |   |   |   |   |   |--- feature_4 >  0.08
# |   |   |   |   |   |   |   |   |--- feature_34 <= 0.51
# |   |   |   |   |   |   |   |   |   |--- feature_40 <= 0.38
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |   |   |   |   |   |   |--- feature_40 >  0.38
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 <= 0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 >  0.48
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_34 >  0.51
# |   |   |   |   |   |   |   |   |   |--- feature_13 <= 0.57
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |   |   |   |   |--- feature_13 >  0.57
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |   |--- feature_38 >  0.54
# |   |   |   |   |   |   |   |--- feature_18 <= 0.47
# |   |   |   |   |   |   |   |   |--- feature_35 <= 0.27
# |   |   |   |   |   |   |   |   |   |--- value: [0.38]
# |   |   |   |   |   |   |   |   |--- feature_35 >  0.27
# |   |   |   |   |   |   |   |   |   |--- value: [0.37]
# |   |   |   |   |   |   |   |--- feature_18 >  0.47
# |   |   |   |   |   |   |   |   |--- feature_27 <= 0.90
# |   |   |   |   |   |   |   |   |   |--- value: [0.32]
# |   |   |   |   |   |   |   |   |--- feature_27 >  0.90
# |   |   |   |   |   |   |   |   |   |--- feature_30 <= 0.40
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.35]
# |   |   |   |   |   |   |   |   |   |--- feature_30 >  0.40
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.34]
# |   |   |   |   |--- feature_38 >  0.64
# |   |   |   |   |   |--- feature_18 <= 0.80
# |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |--- feature_18 >  0.80
# |   |   |   |   |   |   |--- value: [0.17]
# |   |   |--- feature_11 >  0.54
# |   |   |   |--- feature_17 <= 0.44
# |   |   |   |   |--- feature_3 <= 0.42
# |   |   |   |   |   |--- value: [0.20]
# |   |   |   |   |--- feature_3 >  0.42
# |   |   |   |   |   |--- feature_19 <= 0.06
# |   |   |   |   |   |   |--- value: [0.30]
# |   |   |   |   |   |--- feature_19 >  0.06
# |   |   |   |   |   |   |--- value: [0.32]
# |   |   |   |--- feature_17 >  0.44
# |   |   |   |   |--- feature_37 <= 0.55
# |   |   |   |   |   |--- feature_2 <= 0.60
# |   |   |   |   |   |   |--- feature_15 <= 0.68
# |   |   |   |   |   |   |   |--- feature_8 <= 0.49
# |   |   |   |   |   |   |   |   |--- feature_14 <= 0.48
# |   |   |   |   |   |   |   |   |   |--- value: [0.52]
# |   |   |   |   |   |   |   |   |--- feature_14 >  0.48
# |   |   |   |   |   |   |   |   |   |--- value: [0.52]
# |   |   |   |   |   |   |   |--- feature_8 >  0.49
# |   |   |   |   |   |   |   |   |--- value: [0.54]
# |   |   |   |   |   |   |--- feature_15 >  0.68
# |   |   |   |   |   |   |   |--- value: [0.49]
# |   |   |   |   |   |--- feature_2 >  0.60
# |   |   |   |   |   |   |--- value: [0.59]
# |   |   |   |   |--- feature_37 >  0.55
# |   |   |   |   |   |--- feature_4 <= 0.11
# |   |   |   |   |   |   |--- value: [0.38]
# |   |   |   |   |   |--- feature_4 >  0.11
# |   |   |   |   |   |   |--- feature_0 <= 0.12
# |   |   |   |   |   |   |   |--- value: [0.49]
# |   |   |   |   |   |   |--- feature_0 >  0.12
# |   |   |   |   |   |   |   |--- feature_24 <= 0.55
# |   |   |   |   |   |   |   |   |--- value: [0.45]
# |   |   |   |   |   |   |   |--- feature_24 >  0.55
# |   |   |   |   |   |   |   |   |--- value: [0.45]
# |   |--- feature_25 >  0.41
# |   |   |--- feature_13 <= 0.67
# |   |   |   |--- feature_10 <= 0.21
# |   |   |   |   |--- feature_34 <= 0.54
# |   |   |   |   |   |--- feature_9 <= 0.35
# |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |   |--- feature_9 >  0.35
# |   |   |   |   |   |   |--- feature_17 <= 0.76
# |   |   |   |   |   |   |   |--- feature_18 <= 0.58
# |   |   |   |   |   |   |   |   |--- value: [0.27]
# |   |   |   |   |   |   |   |--- feature_18 >  0.58
# |   |   |   |   |   |   |   |   |--- value: [0.26]
# |   |   |   |   |   |   |--- feature_17 >  0.76
# |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |--- feature_34 >  0.54
# |   |   |   |   |   |--- feature_14 <= 0.57
# |   |   |   |   |   |   |--- feature_38 <= 0.57
# |   |   |   |   |   |   |   |--- value: [0.33]
# |   |   |   |   |   |   |--- feature_38 >  0.57
# |   |   |   |   |   |   |   |--- feature_2 <= 0.39
# |   |   |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |   |   |   |--- feature_2 >  0.39
# |   |   |   |   |   |   |   |   |--- feature_39 <= 0.40
# |   |   |   |   |   |   |   |   |   |--- feature_7 <= 0.22
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.40]
# |   |   |   |   |   |   |   |   |   |--- feature_7 >  0.22
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.39]
# |   |   |   |   |   |   |   |   |--- feature_39 >  0.40
# |   |   |   |   |   |   |   |   |   |--- value: [0.41]
# |   |   |   |   |   |--- feature_14 >  0.57
# |   |   |   |   |   |   |--- feature_40 <= 0.69
# |   |   |   |   |   |   |   |--- feature_30 <= 0.43
# |   |   |   |   |   |   |   |   |--- feature_22 <= 0.65
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 0.49
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.32]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  0.49
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.32]
# |   |   |   |   |   |   |   |   |--- feature_22 >  0.65
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.74
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.74
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.30]
# |   |   |   |   |   |   |   |--- feature_30 >  0.43
# |   |   |   |   |   |   |   |   |--- feature_37 <= 0.72
# |   |   |   |   |   |   |   |   |   |--- value: [0.35]
# |   |   |   |   |   |   |   |   |--- feature_37 >  0.72
# |   |   |   |   |   |   |   |   |   |--- value: [0.37]
# |   |   |   |   |   |   |--- feature_40 >  0.69
# |   |   |   |   |   |   |   |--- feature_31 <= 0.60
# |   |   |   |   |   |   |   |   |--- value: [0.29]
# |   |   |   |   |   |   |   |--- feature_31 >  0.60
# |   |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |--- feature_10 >  0.21
# |   |   |   |   |--- feature_10 <= 0.23
# |   |   |   |   |   |--- feature_18 <= 0.50
# |   |   |   |   |   |   |--- value: [0.75]
# |   |   |   |   |   |--- feature_18 >  0.50
# |   |   |   |   |   |   |--- value: [0.70]
# |   |   |   |   |--- feature_10 >  0.23
# |   |   |   |   |   |--- feature_34 <= 0.64
# |   |   |   |   |   |   |--- feature_13 <= 0.47
# |   |   |   |   |   |   |   |--- feature_2 <= 0.41
# |   |   |   |   |   |   |   |   |--- feature_14 <= 0.48
# |   |   |   |   |   |   |   |   |   |--- value: [0.42]
# |   |   |   |   |   |   |   |   |--- feature_14 >  0.48
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= 0.75
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.39]
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  0.75
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.39]
# |   |   |   |   |   |   |   |--- feature_2 >  0.41
# |   |   |   |   |   |   |   |   |--- feature_13 <= 0.40
# |   |   |   |   |   |   |   |   |   |--- feature_17 <= 0.47
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.47]
# |   |   |   |   |   |   |   |   |   |--- feature_17 >  0.47
# |   |   |   |   |   |   |   |   |   |   |--- feature_37 <= 0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |   |   |   |   |   |   |--- feature_37 >  0.45
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |   |   |   |   |--- feature_13 >  0.40
# |   |   |   |   |   |   |   |   |   |--- feature_27 <= 0.40
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.48]
# |   |   |   |   |   |   |   |   |   |--- feature_27 >  0.40
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 <= 0.56
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.50]
# |   |   |   |   |   |   |   |   |   |   |--- feature_0 >  0.56
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.51]
# |   |   |   |   |   |   |--- feature_13 >  0.47
# |   |   |   |   |   |   |   |--- feature_2 <= 0.44
# |   |   |   |   |   |   |   |   |--- value: [0.37]
# |   |   |   |   |   |   |   |--- feature_2 >  0.44
# |   |   |   |   |   |   |   |   |--- feature_32 <= 0.36
# |   |   |   |   |   |   |   |   |   |--- value: [0.36]
# |   |   |   |   |   |   |   |   |--- feature_32 >  0.36
# |   |   |   |   |   |   |   |   |   |--- value: [0.36]
# |   |   |   |   |   |--- feature_34 >  0.64
# |   |   |   |   |   |   |--- feature_35 <= 0.24
# |   |   |   |   |   |   |   |--- feature_2 <= 0.62
# |   |   |   |   |   |   |   |   |--- value: [0.49]
# |   |   |   |   |   |   |   |--- feature_2 >  0.62
# |   |   |   |   |   |   |   |   |--- value: [0.45]
# |   |   |   |   |   |   |--- feature_35 >  0.24
# |   |   |   |   |   |   |   |--- feature_25 <= 0.53
# |   |   |   |   |   |   |   |   |--- feature_22 <= 0.72
# |   |   |   |   |   |   |   |   |   |--- value: [0.56]
# |   |   |   |   |   |   |   |   |--- feature_22 >  0.72
# |   |   |   |   |   |   |   |   |   |--- value: [0.58]
# |   |   |   |   |   |   |   |--- feature_25 >  0.53
# |   |   |   |   |   |   |   |   |--- feature_18 <= 0.65
# |   |   |   |   |   |   |   |   |   |--- value: [0.63]
# |   |   |   |   |   |   |   |   |--- feature_18 >  0.65
# |   |   |   |   |   |   |   |   |   |--- value: [0.62]
# |   |   |--- feature_13 >  0.67
# |   |   |   |--- feature_31 <= 0.60
# |   |   |   |   |--- feature_29 <= 0.82
# |   |   |   |   |   |--- feature_39 <= 0.34
# |   |   |   |   |   |   |--- feature_10 <= 0.32
# |   |   |   |   |   |   |   |--- value: [0.67]
# |   |   |   |   |   |   |--- feature_10 >  0.32
# |   |   |   |   |   |   |   |--- value: [0.70]
# |   |   |   |   |   |--- feature_39 >  0.34
# |   |   |   |   |   |   |--- feature_35 <= 0.38
# |   |   |   |   |   |   |   |--- feature_2 <= 0.41
# |   |   |   |   |   |   |   |   |--- value: [0.60]
# |   |   |   |   |   |   |   |--- feature_2 >  0.41
# |   |   |   |   |   |   |   |   |--- feature_10 <= 0.14
# |   |   |   |   |   |   |   |   |   |--- value: [0.58]
# |   |   |   |   |   |   |   |   |--- feature_10 >  0.14
# |   |   |   |   |   |   |   |   |   |--- value: [0.58]
# |   |   |   |   |   |   |--- feature_35 >  0.38
# |   |   |   |   |   |   |   |--- feature_8 <= 0.07
# |   |   |   |   |   |   |   |   |--- value: [0.51]
# |   |   |   |   |   |   |   |--- feature_8 >  0.07
# |   |   |   |   |   |   |   |   |--- feature_39 <= 0.64
# |   |   |   |   |   |   |   |   |   |--- value: [0.53]
# |   |   |   |   |   |   |   |   |--- feature_39 >  0.64
# |   |   |   |   |   |   |   |   |   |--- value: [0.54]
# |   |   |   |   |--- feature_29 >  0.82
# |   |   |   |   |   |--- value: [0.32]
# |   |   |   |--- feature_31 >  0.60
# |   |   |   |   |--- value: [1.00]

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(regr, filled=True)

# %%
import xgboost
model = xgboost.XGBRegressor()
fit_params={'early_stopping_rounds': 30, 
            'eval_metric': 'mae',
            'verbose': False,
            'eval_set': [[x, y]]}
scores = cross_val_score(model, x, y, 
                         cv = cv, 
                         scoring = 'neg_mean_absolute_error',
                         fit_params = fit_params)

np.mean(np.absolute(scores))
# Out:
# 0.08035247171405675

# %%
scores = cross_val_score(model, x, y, 
                         cv = cv, 
                         scoring = 'r2',
                         fit_params = fit_params)

np.mean(np.absolute(scores))
# Out:
# 0.42678362429821026
