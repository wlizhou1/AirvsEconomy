# %%
import pandas as pd

data = pd.read_csv('Delhi_SO2.txt')

# %%
import numpy as np

# %%
df = data.drop(columns= 'date')
df
# Out:
#        open_SO2  sate_SO2  Alipur, Delhi - DPCC  Anand Vihar, Delhi - DPCC  \
# 0     59.962500    -0.082                 12.09                      11.60
# 1     81.340417     0.062                 16.48                       7.89
# 2     61.284167     0.750                 12.55                      12.05
# 3     39.547917    -0.114                 18.06                       0.72
# 4     41.565000     0.800                 19.28                       1.19
# ..          ...       ...                   ...                        ...
# 398  135.878333     0.134                  7.27                      27.59
# 399  181.317917     0.012                  7.39                      24.14
# 400   62.972500    -1.420                  6.32                      21.75
# 401   66.460417    -0.046                  8.35                      16.72
# 402   46.164583     1.010                  6.15                      21.23
#
#      Ashok Vihar, Delhi - DPCC  Aya Nagar, Delhi - IMD  Bawana, Delhi - DPCC  \
# 0                        11.55               17.520000                 12.68
# 1                        15.64               13.525000                 21.96
# 2                        18.65               19.156667                 15.92
# 3                        14.61               30.203333                 29.25
# 4                        21.67               17.115000                 18.75
# ..                         ...                     ...                   ...
# 398                      12.21               13.543333                  3.26
# 399                      13.07               13.153333                  3.61
# 400                      12.63               14.496667                  2.39
# 401                      15.07               19.376667                  3.49
# 402                      13.23               17.100000                  2.33
#
#      Burari Crossing, Delhi - IMD  Chandni Chowk, Delhi - IITM  \
# 0                         11.7125                        17.89
# 1                         12.9825                        21.79
# 2                         12.8750                        13.48
# 3                         15.2175                        16.14
# 4                         12.3925                         4.00
# ..                            ...                          ...
# 398                       12.2225                        19.68
# 399                       11.0850                        23.74
# 400                       11.8775                         9.60
# 401                       16.7975                         7.86
# 402                       16.2425                        18.71
#
#      CRRI Mathura Road, Delhi - IMD  ...  Pusa, Delhi - DPCC  \
# 0                           11.7125  ...             14.3700
# 1                           12.9825  ...             29.3300
# 2                           12.8750  ...             13.4500
# 3                           15.2175  ...             22.5125
# 4                           12.3925  ...             17.8600
# ..                              ...  ...                 ...
# 398                         12.2225  ...              5.8600
# 399                         11.0850  ...              5.1400
# 400                         11.8775  ...              5.8300
# 401                         16.7975  ...              7.3000
# 402                         16.2425  ...              6.3700
#
#      Pusa, Delhi - IMD  R K Puram, Delhi - DPCC  Rohini, Delhi - DPCC  \
# 0                14.37                    14.80                  5.38
# 1                29.33                    10.92                 12.39
# 2                13.45                    15.85                 10.24
# 3                 9.72                    17.91                 13.88
# 4                 4.38                    12.68                  9.57
# ..                 ...                      ...                   ...
# 398               5.86                    17.92                  6.33
# 399               5.14                    15.51                  6.54
# 400               5.83                    20.30                  6.17
# 401               7.30                    32.74                  7.12
# 402               6.37                    35.17                  6.53
#
#      Shadipur, Delhi - CPCB  Sirifort, Delhi - CPCB  \
# 0                      8.56                   12.40
# 1                     12.62                    7.46
# 2                      5.24                    5.21
# 3                      9.72                    8.10
# 4                      4.38                    4.81
# ..                      ...                     ...
# 398                   10.07                    8.65
# 399                    9.56                   11.15
# 400                    6.29                   10.56
# 401                    6.94                   11.00
# 402                    6.98                    8.87
#
#      Sonia Vihar, Delhi - DPCC  Sri Aurobindo Marg, Delhi - DPCC  \
# 0                         8.95                              7.78
# 1                        16.09                             28.23
# 2                        11.02                              6.30
# 3                        11.11                              9.30
# 4                        23.23                             10.01
# ..                         ...                               ...
# 398                       5.66                              3.22
# 399                       8.27                              2.58
# 400                       4.61                              4.26
# 401                       6.55                              6.43
# 402                       5.16                              5.78
#
#      Vivek Vihar, Delhi - DPCC  Wazirpur, Delhi - DPCC
# 0                        14.45                   10.29
# 1                        19.12                    7.67
# 2                        43.72                   13.92
# 3                        24.02                   14.01
# 4                        39.99                   14.24
# ..                         ...                     ...
# 398                       4.99                    4.25
# 399                       5.13                    4.95
# 400                       3.82                    4.47
# 401                       4.30                    4.20
# 402                       3.97                    3.26
#
# [403 rows x 42 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(df)
df = pd.DataFrame(scaler.transform(df), index=df.index, columns=df.columns)
df
# Out:
#      open_SO2  sate_SO2  Alipur, Delhi - DPCC  Anand Vihar, Delhi - DPCC  \
# 0    0.189605  0.373743              0.192805                   0.212749
# 1    0.284240  0.413966              0.296026                   0.140203
# 2    0.195456  0.606145              0.203621                   0.221549
# 3    0.099234  0.364804              0.333177                   0.000000
# 4    0.108163  0.620112              0.361862                   0.009190
# ..        ...       ...                   ...                        ...
# 398  0.525668  0.434078              0.079473                   0.525420
# 399  0.726819  0.400000              0.082295                   0.457959
# 400  0.202929  0.000000              0.057136                   0.411224
# 401  0.218370  0.383799              0.104867                   0.312867
# 402  0.128524  0.678771              0.053139                   0.401056
#
#      Ashok Vihar, Delhi - DPCC  Aya Nagar, Delhi - IMD  Bawana, Delhi - DPCC  \
# 0                     0.051248                0.391344              0.294968
# 1                     0.140823                0.287806              0.534452
# 2                     0.206746                0.433761              0.378581
# 3                     0.118265                0.720055              0.722581
# 4                     0.272887                0.380847              0.451613
# ..                         ...                     ...                   ...
# 398                   0.065703                0.288281              0.051871
# 399                   0.084538                0.278174              0.060903
# 400                   0.074901                0.312989              0.029419
# 401                   0.128340                0.439463              0.057806
# 402                   0.088042                0.380459              0.027871
#
#      Burari Crossing, Delhi - IMD  Chandni Chowk, Delhi - IITM  \
# 0                        0.228569                     0.489986
# 1                        0.273557                     0.600000
# 2                        0.269748                     0.365585
# 3                        0.352728                     0.440621
# 4                        0.252657                     0.098166
# ..                            ...                          ...
# 398                      0.246635                     0.540480
# 399                      0.206341                     0.655007
# 400                      0.234414                     0.256135
# 401                      0.408696                     0.207052
# 402                      0.389036                     0.513117
#
#      CRRI Mathura Road, Delhi - IMD  ...  Pusa, Delhi - DPCC  \
# 0                          0.228569  ...            0.204550
# 1                          0.273557  ...            0.503093
# 2                          0.269748  ...            0.186190
# 3                          0.352728  ...            0.367043
# 4                          0.252657  ...            0.274197
# ..                              ...  ...                 ...
# 398                        0.246635  ...            0.034724
# 399                        0.206341  ...            0.020355
# 400                        0.234414  ...            0.034125
# 401                        0.408696  ...            0.063460
# 402                        0.389036  ...            0.044901
#
#      Pusa, Delhi - IMD  R K Puram, Delhi - DPCC  Rohini, Delhi - DPCC  \
# 0             0.204550                 0.234145              0.194058
# 1             0.503093                 0.152667              0.529947
# 2             0.186190                 0.256195              0.426929
# 3             0.111754                 0.299454              0.601342
# 4             0.005189                 0.189626              0.394825
# ..                 ...                      ...                   ...
# 398           0.034724                 0.299664              0.239578
# 399           0.020355                 0.249055              0.249641
# 400           0.034125                 0.349643              0.231912
# 401           0.063460                 0.610878              0.277432
# 402           0.044901                 0.661907              0.249161
#
#      Shadipur, Delhi - CPCB  Sirifort, Delhi - CPCB  \
# 0                  0.137339                0.307733
# 1                  0.213099                0.177356
# 2                  0.075387                0.117973
# 3                  0.158985                0.194247
# 4                  0.059339                0.107416
# ..                      ...                     ...
# 398                0.165516                0.208762
# 399                0.155999                0.274743
# 400                0.094980                0.259171
# 401                0.107110                0.270784
# 402                0.107856                0.214568
#
#      Sonia Vihar, Delhi - DPCC  Sri Aurobindo Marg, Delhi - DPCC  \
# 0                     0.126141                          0.205738
# 1                     0.253892                          0.921274
# 2                     0.163178                          0.153954
# 3                     0.164788                          0.258922
# 4                     0.381643                          0.283765
# ..                         ...                               ...
# 398                   0.067275                          0.046186
# 399                   0.113974                          0.023793
# 400                   0.048488                          0.082575
# 401                   0.083199                          0.158502
# 402                   0.058329                          0.135759
#
#      Vivek Vihar, Delhi - DPCC  Wazirpur, Delhi - DPCC
# 0                     0.242891                0.139591
# 1                     0.328564                0.090892
# 2                     0.779857                0.207063
# 3                     0.418455                0.208736
# 4                     0.711429                0.213011
# ..                         ...                     ...
# 398                   0.069345                0.027323
# 399                   0.071913                0.040335
# 400                   0.047881                0.031413
# 401                   0.056687                0.026394
# 402                   0.050633                0.008922
#
# [403 rows x 42 columns]

# %%
ax = df.plot(linewidth=1, fontsize=12);
ax.set_xlabel('Date');
ax.legend(fontsize=2);

# %%
y = df['open_SO2']
x = df.drop(columns =["open_SO2"])

# %%
df.describe()
# Out:
#          open_SO2    sate_SO2  Alipur, Delhi - DPCC  \
# count  403.000000  403.000000            403.000000
# mean     0.229610    0.412498              0.211416
# std      0.135756    0.090392              0.183054
# min      0.000000    0.000000              0.000000
# 25%      0.146861    0.377654              0.070068
# 50%      0.200336    0.407821              0.159182
# 75%      0.285080    0.444134              0.296732
# max      1.000000    1.000000              1.000000
#
#        Anand Vihar, Delhi - DPCC  Ashok Vihar, Delhi - DPCC  \
# count                 403.000000                 403.000000
# mean                    0.316850                   0.298381
# std                     0.177789                   0.198666
# min                     0.000000                   0.000000
# 25%                     0.184591                   0.157906
# 50%                     0.310325                   0.250767
# 75%                     0.421979                   0.374945
# max                     1.000000                   1.000000
#
#        Aya Nagar, Delhi - IMD  Bawana, Delhi - DPCC  \
# count              403.000000            403.000000
# mean                 0.243962              0.162708
# std                  0.165836              0.159210
# min                  0.000000              0.000000
# 25%                  0.102760              0.056774
# 50%                  0.209926              0.111226
# 75%                  0.335061              0.192387
# max                  1.000000              1.000000
#
#        Burari Crossing, Delhi - IMD  Chandni Chowk, Delhi - IITM  \
# count                    403.000000                   403.000000
# mean                       0.282334                     0.172562
# std                        0.177028                     0.148146
# min                        0.000000                     0.000000
# 25%                        0.134166                     0.077574
# 50%                        0.258856                     0.121298
# 75%                        0.397272                     0.224965
# max                        1.000000                     1.000000
#
#        CRRI Mathura Road, Delhi - IMD  ...  Pusa, Delhi - DPCC  \
# count                      403.000000  ...          403.000000
# mean                         0.282334  ...            0.242581
# std                          0.177028  ...            0.191237
# min                          0.000000  ...            0.000000
# 25%                          0.134166  ...            0.086609
# 50%                          0.258856  ...            0.186190
# 75%                          0.397272  ...            0.362403
# max                          1.000000  ...            1.000000
#
#        Pusa, Delhi - IMD  R K Puram, Delhi - DPCC  Rohini, Delhi - DPCC  \
# count         403.000000               403.000000            403.000000
# mean            0.240199                 0.293885              0.255593
# std             0.191953                 0.162375              0.211377
# min             0.000000                 0.000000              0.000000
# 25%             0.085811                 0.164112              0.100144
# 50%             0.180403                 0.270055              0.196933
# 75%             0.359210                 0.384817              0.339483
# max             1.000000                 1.000000              1.000000
#
#        Shadipur, Delhi - CPCB  Sirifort, Delhi - CPCB  \
# count              403.000000              403.000000
# mean                 0.175416                0.195592
# std                  0.127533                0.134024
# min                  0.000000                0.000000
# 25%                  0.088356                0.104018
# 50%                  0.138459                0.158089
# 75%                  0.215712                0.256268
# max                  1.000000                1.000000
#
#        Sonia Vihar, Delhi - DPCC  Sri Aurobindo Marg, Delhi - DPCC  \
# count                 403.000000                        403.000000
# mean                    0.205396                          0.212547
# std                     0.107109                          0.154030
# min                     0.000000                          0.000000
# 25%                     0.123099                          0.115815
# 50%                     0.192342                          0.174598
# 75%                     0.263822                          0.261721
# max                     1.000000                          1.000000
#
#        Vivek Vihar, Delhi - DPCC  Wazirpur, Delhi - DPCC
# count                 403.000000              403.000000
# mean                    0.211884                0.143341
# std                     0.193076                0.154195
# min                     0.000000                0.000000
# 25%                     0.059347                0.029368
# 50%                     0.135571                0.068401
# 75%                     0.350853                0.227695
# max                     1.000000                1.000000
#
# [8 rows x 42 columns]

# %% [markdown]
# # Normal OLS

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression


cv = KFold(n_splits=10, random_state=1, shuffle=True)
model = LinearRegression().fit(x,y)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.09287011438209933

# %%
scores = cross_val_score(model, x, y, scoring='r2',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.15041646378787332

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_predict


predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # LASSO

# %%
from sklearn import linear_model
import warnings
warnings.filterwarnings("ignore")
model = linear_model.Lasso(alpha=0.1)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.09844181367549373

# %%
scores = cross_val_score(model, x, y, scoring='r2',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.01611410398286428

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # Ridge

# %%
from sklearn.linear_model import Ridge
model = Ridge(alpha=0.1)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.09138309968240907

# %%
scores = cross_val_score(model, x, y, scoring='r2',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.13854900790629127

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # Elastic Net

# %%
from sklearn.linear_model import ElasticNet
model = ElasticNet(random_state=0)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.09844181367549373

# %%
scores = cross_val_score(model, x, y, scoring='r2',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.01611410398286428

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # Decision tree

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.12070337243301495

# %%
scores = cross_val_score(model, x, y, scoring='r2',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 0.6224447757798408

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %%
regr = tree.DecisionTreeRegressor()
model = regr.fit(x, y)
text_representation = tree.export_text(regr)
print(text_representation)
# Out:
# |--- feature_12 <= 0.58
# |   |--- feature_12 <= 0.32
# |   |   |--- feature_0 <= 0.17
# |   |   |   |--- value: [0.57]
# |   |   |--- feature_0 >  0.17
# |   |   |   |--- feature_2 <= 0.45
# |   |   |   |   |--- feature_25 <= 0.05
# |   |   |   |   |   |--- feature_28 <= 0.19
# |   |   |   |   |   |   |--- feature_14 <= 0.22
# |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |   |   |   |--- feature_14 >  0.22
# |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |--- feature_28 >  0.19
# |   |   |   |   |   |   |--- feature_23 <= 0.01
# |   |   |   |   |   |   |   |--- feature_40 <= 0.02
# |   |   |   |   |   |   |   |   |--- value: [0.19]
# |   |   |   |   |   |   |   |--- feature_40 >  0.02
# |   |   |   |   |   |   |   |   |--- value: [0.19]
# |   |   |   |   |   |   |--- feature_23 >  0.01
# |   |   |   |   |   |   |   |--- feature_35 <= 0.05
# |   |   |   |   |   |   |   |   |--- value: [0.18]
# |   |   |   |   |   |   |   |--- feature_35 >  0.05
# |   |   |   |   |   |   |   |   |--- feature_27 <= 0.04
# |   |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |   |   |--- feature_27 >  0.04
# |   |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |--- feature_25 >  0.05
# |   |   |   |   |   |--- feature_22 <= 0.34
# |   |   |   |   |   |   |--- feature_15 <= 0.06
# |   |   |   |   |   |   |   |--- feature_36 <= 0.11
# |   |   |   |   |   |   |   |   |--- feature_21 <= 0.35
# |   |   |   |   |   |   |   |   |   |--- feature_38 <= 0.23
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_38 >  0.23
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 <= 0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 >  0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_21 >  0.35
# |   |   |   |   |   |   |   |   |   |--- feature_4 <= 0.39
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 <= 0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 >  0.29
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |   |   |   |   |--- feature_4 >  0.39
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 <= 0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 >  0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_36 >  0.11
# |   |   |   |   |   |   |   |   |--- feature_38 <= 0.16
# |   |   |   |   |   |   |   |   |   |--- feature_30 <= 0.12
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |   |   |   |   |--- feature_30 >  0.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 <= 0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 >  0.17
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_38 >  0.16
# |   |   |   |   |   |   |   |   |   |--- feature_27 <= 0.14
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.11
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.01]
# |   |   |   |   |   |   |   |   |   |--- feature_27 >  0.14
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.03]
# |   |   |   |   |   |   |--- feature_15 >  0.06
# |   |   |   |   |   |   |   |--- feature_10 <= 0.24
# |   |   |   |   |   |   |   |   |--- feature_18 <= 0.22
# |   |   |   |   |   |   |   |   |   |--- feature_26 <= 0.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_22 <= 0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_22 >  0.14
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |   |   |   |   |   |--- feature_26 >  0.18
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_18 >  0.22
# |   |   |   |   |   |   |   |   |   |--- feature_38 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |   |   |   |--- feature_38 >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 <= 0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.19]
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 >  0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.19]
# |   |   |   |   |   |   |   |--- feature_10 >  0.24
# |   |   |   |   |   |   |   |   |--- value: [0.35]
# |   |   |   |   |   |--- feature_22 >  0.34
# |   |   |   |   |   |   |--- feature_9 <= 0.16
# |   |   |   |   |   |   |   |--- feature_38 <= 0.12
# |   |   |   |   |   |   |   |   |--- feature_23 <= 0.04
# |   |   |   |   |   |   |   |   |   |--- feature_39 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |   |   |   |   |   |   |--- feature_39 >  0.02
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |   |   |   |   |--- feature_23 >  0.04
# |   |   |   |   |   |   |   |   |   |--- feature_32 <= 0.05
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |   |   |   |   |--- feature_32 >  0.05
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |   |   |   |   |--- feature_38 >  0.12
# |   |   |   |   |   |   |   |   |--- feature_29 <= 0.13
# |   |   |   |   |   |   |   |   |   |--- feature_39 <= 0.05
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.13]
# |   |   |   |   |   |   |   |   |   |--- feature_39 >  0.05
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |   |   |   |--- feature_29 >  0.13
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.04
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.04
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.18]
# |   |   |   |   |   |   |--- feature_9 >  0.16
# |   |   |   |   |   |   |   |--- feature_17 <= 0.08
# |   |   |   |   |   |   |   |   |--- feature_5 <= 0.03
# |   |   |   |   |   |   |   |   |   |--- value: [0.09]
# |   |   |   |   |   |   |   |   |--- feature_5 >  0.03
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 0.12
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  0.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 <= 0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |   |   |   |   |   |--- feature_8 >  0.06
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.07]
# |   |   |   |   |   |   |   |--- feature_17 >  0.08
# |   |   |   |   |   |   |   |   |--- feature_27 <= 0.03
# |   |   |   |   |   |   |   |   |   |--- value: [0.18]
# |   |   |   |   |   |   |   |   |--- feature_27 >  0.03
# |   |   |   |   |   |   |   |   |   |--- feature_26 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |   |   |   |   |   |--- feature_26 >  0.09
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |--- feature_2 >  0.45
# |   |   |   |   |--- feature_34 <= 0.16
# |   |   |   |   |   |--- feature_0 <= 0.45
# |   |   |   |   |   |   |--- value: [0.36]
# |   |   |   |   |   |--- feature_0 >  0.45
# |   |   |   |   |   |   |--- value: [0.37]
# |   |   |   |   |--- feature_34 >  0.16
# |   |   |   |   |   |--- value: [0.33]
# |   |--- feature_12 >  0.32
# |   |   |--- feature_37 <= 0.05
# |   |   |   |--- value: [0.79]
# |   |   |--- feature_37 >  0.05
# |   |   |   |--- feature_31 <= 0.02
# |   |   |   |   |--- feature_23 <= 0.04
# |   |   |   |   |   |--- feature_19 <= 0.24
# |   |   |   |   |   |   |--- value: [0.28]
# |   |   |   |   |   |--- feature_19 >  0.24
# |   |   |   |   |   |   |--- value: [0.37]
# |   |   |   |   |--- feature_23 >  0.04
# |   |   |   |   |   |--- value: [0.73]
# |   |   |   |--- feature_31 >  0.02
# |   |   |   |   |--- feature_6 <= 0.04
# |   |   |   |   |   |--- value: [0.62]
# |   |   |   |   |--- feature_6 >  0.04
# |   |   |   |   |   |--- feature_12 <= 0.33
# |   |   |   |   |   |   |--- feature_24 <= 0.37
# |   |   |   |   |   |   |   |--- feature_3 <= 0.04
# |   |   |   |   |   |   |   |   |--- feature_1 <= 0.07
# |   |   |   |   |   |   |   |   |   |--- value: [0.58]
# |   |   |   |   |   |   |   |   |--- feature_1 >  0.07
# |   |   |   |   |   |   |   |   |   |--- value: [0.45]
# |   |   |   |   |   |   |   |--- feature_3 >  0.04
# |   |   |   |   |   |   |   |   |--- feature_15 <= 0.06
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.33
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 <= 0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_6 >  0.13
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.33
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.16]
# |   |   |   |   |   |   |   |   |--- feature_15 >  0.06
# |   |   |   |   |   |   |   |   |   |--- feature_21 <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |   |   |   |--- feature_21 >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- feature_24 <= 0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_24 >  0.21
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.14]
# |   |   |   |   |   |   |--- feature_24 >  0.37
# |   |   |   |   |   |   |   |--- value: [1.00]
# |   |   |   |   |   |--- feature_12 >  0.33
# |   |   |   |   |   |   |--- feature_40 <= 0.03
# |   |   |   |   |   |   |   |--- feature_5 <= 0.03
# |   |   |   |   |   |   |   |   |--- feature_39 <= 0.03
# |   |   |   |   |   |   |   |   |   |--- feature_38 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 <= 0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 >  0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.04]
# |   |   |   |   |   |   |   |   |   |--- feature_38 >  0.16
# |   |   |   |   |   |   |   |   |   |   |--- feature_28 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.18]
# |   |   |   |   |   |   |   |   |   |   |--- feature_28 >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.15]
# |   |   |   |   |   |   |   |   |--- feature_39 >  0.03
# |   |   |   |   |   |   |   |   |   |--- feature_30 <= 0.31
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.13]
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  0.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |   |   |   |--- feature_30 >  0.31
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 <= 0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_5 >  0.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_5 >  0.03
# |   |   |   |   |   |   |   |   |--- feature_32 <= 0.31
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= 0.16
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 <= 0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |   |--- feature_18 >  0.20
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.10]
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  0.16
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- feature_32 >  0.31
# |   |   |   |   |   |   |   |   |   |--- value: [0.54]
# |   |   |   |   |   |   |--- feature_40 >  0.03
# |   |   |   |   |   |   |   |--- feature_9 <= 0.56
# |   |   |   |   |   |   |   |   |--- feature_12 <= 0.44
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 0.38
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  0.26
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  0.38
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 <= 0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 >  0.41
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_12 >  0.44
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.15
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.63]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  0.17
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 <= 0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 >  0.05
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |--- feature_9 >  0.56
# |   |   |   |   |   |   |   |   |--- feature_11 <= 0.56
# |   |   |   |   |   |   |   |   |   |--- feature_18 <= 0.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 <= 0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 >  0.23
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |   |   |   |--- feature_18 >  0.11
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 <= 0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 >  0.62
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.32]
# |   |   |   |   |   |   |   |   |--- feature_11 >  0.56
# |   |   |   |   |   |   |   |   |   |--- value: [0.56]
# |--- feature_12 >  0.58
# |   |--- feature_37 <= 0.08
# |   |   |--- feature_36 <= 0.35
# |   |   |   |--- feature_4 <= 0.32
# |   |   |   |   |--- value: [0.50]
# |   |   |   |--- feature_4 >  0.32
# |   |   |   |   |--- value: [0.54]
# |   |   |--- feature_36 >  0.35
# |   |   |   |--- value: [0.81]
# |   |--- feature_37 >  0.08
# |   |   |--- feature_29 <= 0.89
# |   |   |   |--- feature_13 <= 0.36
# |   |   |   |   |--- feature_17 <= 0.29
# |   |   |   |   |   |--- feature_10 <= 0.10
# |   |   |   |   |   |   |--- feature_0 <= 0.37
# |   |   |   |   |   |   |   |--- value: [0.70]
# |   |   |   |   |   |   |--- feature_0 >  0.37
# |   |   |   |   |   |   |   |--- feature_2 <= 0.15
# |   |   |   |   |   |   |   |   |--- value: [0.39]
# |   |   |   |   |   |   |   |--- feature_2 >  0.15
# |   |   |   |   |   |   |   |   |--- feature_15 <= 0.12
# |   |   |   |   |   |   |   |   |   |--- value: [0.51]
# |   |   |   |   |   |   |   |   |--- feature_15 >  0.12
# |   |   |   |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |   |--- feature_10 >  0.10
# |   |   |   |   |   |   |--- feature_16 <= 0.18
# |   |   |   |   |   |   |   |--- feature_37 <= 0.13
# |   |   |   |   |   |   |   |   |--- feature_32 <= 0.06
# |   |   |   |   |   |   |   |   |   |--- value: [0.22]
# |   |   |   |   |   |   |   |   |--- feature_32 >  0.06
# |   |   |   |   |   |   |   |   |   |--- feature_36 <= 0.19
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.35]
# |   |   |   |   |   |   |   |   |   |--- feature_36 >  0.19
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.32]
# |   |   |   |   |   |   |   |--- feature_37 >  0.13
# |   |   |   |   |   |   |   |   |--- feature_32 <= 0.11
# |   |   |   |   |   |   |   |   |   |--- feature_24 <= 0.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 <= 0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.43]
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 >  0.24
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.43]
# |   |   |   |   |   |   |   |   |   |--- feature_24 >  0.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 <= 0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 >  0.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.40]
# |   |   |   |   |   |   |   |   |--- feature_32 >  0.11
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 0.20
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.47]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  0.20
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.46]
# |   |   |   |   |   |   |--- feature_16 >  0.18
# |   |   |   |   |   |   |   |--- feature_31 <= 0.05
# |   |   |   |   |   |   |   |   |--- feature_35 <= 0.16
# |   |   |   |   |   |   |   |   |   |--- value: [0.35]
# |   |   |   |   |   |   |   |   |--- feature_35 >  0.16
# |   |   |   |   |   |   |   |   |   |--- value: [0.50]
# |   |   |   |   |   |   |   |--- feature_31 >  0.05
# |   |   |   |   |   |   |   |   |--- feature_17 <= 0.27
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 0.64
# |   |   |   |   |   |   |   |   |   |   |--- feature_23 <= 0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_23 >  0.09
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  0.64
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 <= 0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 >  0.19
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |--- feature_17 >  0.27
# |   |   |   |   |   |   |   |   |   |--- feature_26 <= 0.40
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.40]
# |   |   |   |   |   |   |   |   |   |--- feature_26 >  0.40
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.34]
# |   |   |   |   |--- feature_17 >  0.29
# |   |   |   |   |   |--- feature_5 <= 0.11
# |   |   |   |   |   |   |--- feature_7 <= 0.09
# |   |   |   |   |   |   |   |--- feature_36 <= 0.54
# |   |   |   |   |   |   |   |   |--- value: [0.23]
# |   |   |   |   |   |   |   |--- feature_36 >  0.54
# |   |   |   |   |   |   |   |   |--- value: [0.19]
# |   |   |   |   |   |   |--- feature_7 >  0.09
# |   |   |   |   |   |   |   |--- feature_28 <= 0.30
# |   |   |   |   |   |   |   |   |--- feature_8 <= 0.36
# |   |   |   |   |   |   |   |   |   |--- value: [0.15]
# |   |   |   |   |   |   |   |   |--- feature_8 >  0.36
# |   |   |   |   |   |   |   |   |   |--- value: [0.15]
# |   |   |   |   |   |   |   |--- feature_28 >  0.30
# |   |   |   |   |   |   |   |   |--- feature_16 <= 0.10
# |   |   |   |   |   |   |   |   |   |--- value: [0.08]
# |   |   |   |   |   |   |   |   |--- feature_16 >  0.10
# |   |   |   |   |   |   |   |   |   |--- feature_19 <= 0.35
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |   |   |   |   |--- feature_19 >  0.35
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.11]
# |   |   |   |   |   |--- feature_5 >  0.11
# |   |   |   |   |   |   |--- feature_40 <= 0.12
# |   |   |   |   |   |   |   |--- feature_39 <= 0.48
# |   |   |   |   |   |   |   |   |--- feature_22 <= 0.35
# |   |   |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |   |   |   |--- feature_22 >  0.35
# |   |   |   |   |   |   |   |   |   |--- value: [0.32]
# |   |   |   |   |   |   |   |--- feature_39 >  0.48
# |   |   |   |   |   |   |   |   |--- value: [0.43]
# |   |   |   |   |   |   |--- feature_40 >  0.12
# |   |   |   |   |   |   |   |--- feature_25 <= 0.86
# |   |   |   |   |   |   |   |   |--- feature_23 <= 0.26
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 0.22
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 <= 0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_40 >  0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  0.22
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 <= 0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 >  0.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_23 >  0.26
# |   |   |   |   |   |   |   |   |   |--- feature_22 <= 0.82
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 <= 0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_1 >  0.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_22 >  0.82
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.24]
# |   |   |   |   |   |   |   |--- feature_25 >  0.86
# |   |   |   |   |   |   |   |   |--- feature_39 <= 0.28
# |   |   |   |   |   |   |   |   |   |--- value: [0.41]
# |   |   |   |   |   |   |   |   |--- feature_39 >  0.28
# |   |   |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |--- feature_13 >  0.36
# |   |   |   |   |--- feature_18 <= 0.18
# |   |   |   |   |   |--- feature_34 <= 0.40
# |   |   |   |   |   |   |--- feature_17 <= 0.32
# |   |   |   |   |   |   |   |--- feature_17 <= 0.31
# |   |   |   |   |   |   |   |   |--- value: [0.61]
# |   |   |   |   |   |   |   |--- feature_17 >  0.31
# |   |   |   |   |   |   |   |   |--- value: [0.64]
# |   |   |   |   |   |   |--- feature_17 >  0.32
# |   |   |   |   |   |   |   |--- feature_21 <= 0.47
# |   |   |   |   |   |   |   |   |--- value: [0.54]
# |   |   |   |   |   |   |   |--- feature_21 >  0.47
# |   |   |   |   |   |   |   |   |--- value: [0.57]
# |   |   |   |   |   |--- feature_34 >  0.40
# |   |   |   |   |   |   |--- feature_26 <= 0.47
# |   |   |   |   |   |   |   |--- feature_33 <= 0.40
# |   |   |   |   |   |   |   |   |--- value: [0.34]
# |   |   |   |   |   |   |   |--- feature_33 >  0.40
# |   |   |   |   |   |   |   |   |--- value: [0.32]
# |   |   |   |   |   |   |--- feature_26 >  0.47
# |   |   |   |   |   |   |   |--- feature_12 <= 0.74
# |   |   |   |   |   |   |   |   |--- value: [0.36]
# |   |   |   |   |   |   |   |--- feature_12 >  0.74
# |   |   |   |   |   |   |   |   |--- value: [0.38]
# |   |   |   |   |--- feature_18 >  0.18
# |   |   |   |   |   |--- feature_18 <= 0.51
# |   |   |   |   |   |   |--- feature_22 <= 0.33
# |   |   |   |   |   |   |   |--- feature_35 <= 0.33
# |   |   |   |   |   |   |   |   |--- feature_36 <= 0.59
# |   |   |   |   |   |   |   |   |   |--- value: [0.17]
# |   |   |   |   |   |   |   |   |--- feature_36 >  0.59
# |   |   |   |   |   |   |   |   |   |--- value: [0.15]
# |   |   |   |   |   |   |   |--- feature_35 >  0.33
# |   |   |   |   |   |   |   |   |--- value: [0.12]
# |   |   |   |   |   |   |--- feature_22 >  0.33
# |   |   |   |   |   |   |   |--- feature_6 <= 0.44
# |   |   |   |   |   |   |   |   |--- feature_16 <= 0.18
# |   |   |   |   |   |   |   |   |   |--- value: [0.32]
# |   |   |   |   |   |   |   |   |--- feature_16 >  0.18
# |   |   |   |   |   |   |   |   |   |--- value: [0.34]
# |   |   |   |   |   |   |   |--- feature_6 >  0.44
# |   |   |   |   |   |   |   |   |--- feature_5 <= 0.43
# |   |   |   |   |   |   |   |   |   |--- value: [0.27]
# |   |   |   |   |   |   |   |   |--- feature_5 >  0.43
# |   |   |   |   |   |   |   |   |   |--- value: [0.30]
# |   |   |   |   |   |--- feature_18 >  0.51
# |   |   |   |   |   |   |--- feature_0 <= 0.39
# |   |   |   |   |   |   |   |--- feature_1 <= 0.38
# |   |   |   |   |   |   |   |   |--- value: [0.42]
# |   |   |   |   |   |   |   |--- feature_1 >  0.38
# |   |   |   |   |   |   |   |   |--- value: [0.43]
# |   |   |   |   |   |   |--- feature_0 >  0.39
# |   |   |   |   |   |   |   |--- feature_36 <= 0.23
# |   |   |   |   |   |   |   |   |--- value: [0.31]
# |   |   |   |   |   |   |   |--- feature_36 >  0.23
# |   |   |   |   |   |   |   |   |--- feature_21 <= 0.28
# |   |   |   |   |   |   |   |   |   |--- value: [0.36]
# |   |   |   |   |   |   |   |   |--- feature_21 >  0.28
# |   |   |   |   |   |   |   |   |   |--- feature_26 <= 0.41
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.38]
# |   |   |   |   |   |   |   |   |   |--- feature_26 >  0.41
# |   |   |   |   |   |   |   |   |   |   |--- value: [0.38]
# |   |   |--- feature_29 >  0.89
# |   |   |   |--- feature_8 <= 0.54
# |   |   |   |   |--- feature_26 <= 0.46
# |   |   |   |   |   |--- value: [0.53]
# |   |   |   |   |--- feature_26 >  0.46
# |   |   |   |   |   |--- value: [0.48]
# |   |   |   |--- feature_8 >  0.54
# |   |   |   |   |--- value: [0.64]

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(regr, filled=True)

# %%
import xgboost
model = xgboost.XGBRegressor()
fit_params={'early_stopping_rounds': 30, 
            'eval_metric': 'mae',
            'verbose': False,
            'eval_set': [[x, y]]}
scores = cross_val_score(model, x, y, 
                         cv = cv, 
                         scoring = 'neg_mean_absolute_error',
                         fit_params = fit_params)

np.mean(np.absolute(scores))
# Out:
# 0.09648207256927697

# %%
scores = cross_val_score(model, x, y, 
                         cv = cv, 
                         scoring = 'r2',
                         fit_params = fit_params)

np.mean(np.absolute(scores))
# Out:
# 0.13644363171647406
