# %%
import pandas as pd

df = pd.read_csv('Delhi_SO2.txt')

# %%
import numpy as np

# %%
df
# Out:
#            date    open_SO2  sate_SO2  Alipur, Delhi - DPCC  \
# 0    2020-11-24   59.962500    -0.082                 12.09
# 1    2020-11-25   81.340417     0.062                 16.48
# 2    2020-11-26   61.284167     0.750                 12.55
# 3    2020-11-27   39.547917    -0.114                 18.06
# 4    2020-11-28   41.565000     0.800                 19.28
# ..          ...         ...       ...                   ...
# 398  2021-12-27  135.878333     0.134                  7.27
# 399  2021-12-28  181.317917     0.012                  7.39
# 400  2021-12-29   62.972500    -1.420                  6.32
# 401  2021-12-30   66.460417    -0.046                  8.35
# 402  2021-12-31   46.164583     1.010                  6.15
#
#      Anand Vihar, Delhi - DPCC  Ashok Vihar, Delhi - DPCC  \
# 0                        11.60                      11.55
# 1                         7.89                      15.64
# 2                        12.05                      18.65
# 3                         0.72                      14.61
# 4                         1.19                      21.67
# ..                         ...                        ...
# 398                      27.59                      12.21
# 399                      24.14                      13.07
# 400                      21.75                      12.63
# 401                      16.72                      15.07
# 402                      21.23                      13.23
#
#      Aya Nagar, Delhi - IMD  Bawana, Delhi - DPCC  \
# 0                 17.520000                 12.68
# 1                 13.525000                 21.96
# 2                 19.156667                 15.92
# 3                 30.203333                 29.25
# 4                 17.115000                 18.75
# ..                      ...                   ...
# 398               13.543333                  3.26
# 399               13.153333                  3.61
# 400               14.496667                  2.39
# 401               19.376667                  3.49
# 402               17.100000                  2.33
#
#      Burari Crossing, Delhi - IMD  Chandni Chowk, Delhi - IITM  ...  \
# 0                         11.7125                        17.89  ...
# 1                         12.9825                        21.79  ...
# 2                         12.8750                        13.48  ...
# 3                         15.2175                        16.14  ...
# 4                         12.3925                         4.00  ...
# ..                            ...                          ...  ...
# 398                       12.2225                        19.68  ...
# 399                       11.0850                        23.74  ...
# 400                       11.8775                         9.60  ...
# 401                       16.7975                         7.86  ...
# 402                       16.2425                        18.71  ...
#
#      Pusa, Delhi - DPCC  Pusa, Delhi - IMD  R K Puram, Delhi - DPCC  \
# 0               14.3700              14.37                    14.80
# 1               29.3300              29.33                    10.92
# 2               13.4500              13.45                    15.85
# 3               22.5125               9.72                    17.91
# 4               17.8600               4.38                    12.68
# ..                  ...                ...                      ...
# 398              5.8600               5.86                    17.92
# 399              5.1400               5.14                    15.51
# 400              5.8300               5.83                    20.30
# 401              7.3000               7.30                    32.74
# 402              6.3700               6.37                    35.17
#
#      Rohini, Delhi - DPCC  Shadipur, Delhi - CPCB  Sirifort, Delhi - CPCB  \
# 0                    5.38                    8.56                   12.40
# 1                   12.39                   12.62                    7.46
# 2                   10.24                    5.24                    5.21
# 3                   13.88                    9.72                    8.10
# 4                    9.57                    4.38                    4.81
# ..                    ...                     ...                     ...
# 398                  6.33                   10.07                    8.65
# 399                  6.54                    9.56                   11.15
# 400                  6.17                    6.29                   10.56
# 401                  7.12                    6.94                   11.00
# 402                  6.53                    6.98                    8.87
#
#      Sonia Vihar, Delhi - DPCC  Sri Aurobindo Marg, Delhi - DPCC  \
# 0                         8.95                              7.78
# 1                        16.09                             28.23
# 2                        11.02                              6.30
# 3                        11.11                              9.30
# 4                        23.23                             10.01
# ..                         ...                               ...
# 398                       5.66                              3.22
# 399                       8.27                              2.58
# 400                       4.61                              4.26
# 401                       6.55                              6.43
# 402                       5.16                              5.78
#
#      Vivek Vihar, Delhi - DPCC  Wazirpur, Delhi - DPCC
# 0                        14.45                   10.29
# 1                        19.12                    7.67
# 2                        43.72                   13.92
# 3                        24.02                   14.01
# 4                        39.99                   14.24
# ..                         ...                     ...
# 398                       4.99                    4.25
# 399                       5.13                    4.95
# 400                       3.82                    4.47
# 401                       4.30                    4.20
# 402                       3.97                    3.26
#
# [403 rows x 43 columns]

# %%
ax = df.plot(linewidth=1, fontsize=12);
ax.set_xlabel('Date');
ax.legend(fontsize=2);

# %%
df['date'] = pd.to_datetime(df['date'],format='%Y-%m-%d')

# %%
y = df['open_SO2']
x = df.drop(columns =["date", "open_SO2"])

# %%
df.describe()
# Out:
#          open_SO2    sate_SO2  Alipur, Delhi - DPCC  \
# count  403.000000  403.000000            403.000000
# mean    68.999474    0.056743             12.881522
# std     30.666910    0.323602              7.785297
# min     17.131250   -1.420000              3.890000
# 25%     50.306875   -0.068000              6.870000
# 50%     62.386667    0.040000             10.660000
# 75%     81.530000    0.170000             16.510000
# max    243.028750    2.160000             46.420000
#
#        Anand Vihar, Delhi - DPCC  Ashok Vihar, Delhi - DPCC  \
# count                 403.000000                 403.000000
# mean                   16.923697                  22.834069
# std                     9.092115                   9.071095
# min                     0.720000                   9.210000
# 25%                    10.160000                  16.420000
# 50%                    16.590000                  20.660000
# 75%                    22.300000                  26.330000
# max                    51.860000                  54.870000
#
#        Aya Nagar, Delhi - IMD  Bawana, Delhi - DPCC  \
# count              403.000000            403.000000
# mean                11.833259              7.554938
# std                  6.398780              6.169377
# min                  2.420000              1.250000
# 25%                  6.385000              3.450000
# 50%                 10.520000              5.560000
# 75%                 15.348333              8.705000
# max                 41.005000             40.000000
#
#        Burari Crossing, Delhi - IMD  Chandni Chowk, Delhi - IITM  \
# count                    403.000000                    403.00000
# mean                      13.230302                      6.63732
# std                        4.997501                      5.25179
# min                        5.260000                      0.52000
# 25%                        9.047500                      3.27000
# 50%                       12.567500                      4.82000
# 75%                       16.475000                      8.49500
# max                       33.490000                     35.97000
#
#        CRRI Mathura Road, Delhi - IMD  ...  Pusa, Delhi - DPCC  \
# count                      403.000000  ...          403.000000
# mean                        13.230302  ...           16.275722
# std                          4.997501  ...            9.582878
# min                          5.260000  ...            4.120000
# 25%                          9.047500  ...            8.460000
# 50%                         12.567500  ...           13.450000
# 75%                         16.475000  ...           22.280000
# max                         33.490000  ...           54.230000
#
#        Pusa, Delhi - IMD  R K Puram, Delhi - DPCC  Rohini, Delhi - DPCC  \
# count         403.000000               403.000000            403.000000
# mean           16.156377                17.644789              6.664218
# std             9.618757                 7.732293              4.411444
# min             4.120000                 3.650000              1.330000
# 25%             8.420000                11.465000              3.420000
# 50%            13.160000                16.510000              5.440000
# 75%            22.120000                21.975000              8.415000
# max            54.230000                51.270000             22.200000
#
#        Shadipur, Delhi - CPCB  Sirifort, Delhi - CPCB  \
# count              403.000000              403.000000
# mean                10.600521                8.150999
# std                  6.834478                5.078179
# min                  1.200000                0.740000
# 25%                  5.935000                4.681250
# 50%                  8.620000                6.730000
# 75%                 12.760000               10.450000
# max                 54.790000               38.630000
#
#        Sonia Vihar, Delhi - DPCC  Sri Aurobindo Marg, Delhi - DPCC  \
# count                 403.000000                        403.000000
# mean                   13.379603                          7.974591
# std                     5.986313                          4.402177
# min                     1.900000                          1.900000
# 25%                     8.780000                          5.210000
# 50%                    12.650000                          6.890000
# 75%                    16.645000                          9.380000
# max                    57.790000                         30.480000
#
#        Vivek Vihar, Delhi - DPCC  Wazirpur, Delhi - DPCC
# count                 403.000000              403.000000
# mean                   12.759813               10.491766
# std                    10.524549                8.295668
# min                     1.210000                2.780000
# 25%                     4.445000                4.360000
# 50%                     8.600000                6.460000
# 75%                    20.335000               15.030000
# max                    55.720000               56.580000
#
# [8 rows x 42 columns]

# %% [markdown]
# # Normal OLS

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression


cv = KFold(n_splits=10, random_state=1, shuffle=True)
model = LinearRegression().fit(x,y)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 20.978042249572002

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_predict


predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # LASSO

# %%
from sklearn import linear_model
import warnings
warnings.filterwarnings("ignore")
model = linear_model.Lasso(alpha=0.1)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 20.87676802279517

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # Ridge

# %%
from sklearn.linear_model import Ridge
model = Ridge(alpha=0.1)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 20.97704379400447

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # Elastic Net

# %%
from sklearn.linear_model import ElasticNet
model = ElasticNet(random_state=0)
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 20.502788857368365

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %% [markdown]
# # Decision tree

# %%
from sklearn import tree
model = tree.DecisionTreeRegressor()
scores = cross_val_score(model, x, y, scoring='neg_mean_absolute_error',
                         cv=cv, n_jobs=-1)
np.mean(np.absolute(scores))
# Out:
# 26.187684388520676

# %%
predicted = cross_val_predict(model, x, y, cv=10)
fig, ax = plt.subplots()
ax.scatter(y, predicted, edgecolors=(0, 0, 0))
ax.plot([y.min(), y.max()], [y.min(), y.max()], "k--", lw=4)
ax.set_xlabel("Measured")
ax.set_ylabel("Predicted")
plt.show()

# %%
regr = tree.DecisionTreeRegressor()
model = regr.fit(x, y)
text_representation = tree.export_text(regr)
print(text_representation)
# Out:
# |--- feature_12 <= 29.19
# |   |--- feature_12 <= 16.51
# |   |   |--- feature_25 <= 17.71
# |   |   |   |--- feature_2 <= 23.72
# |   |   |   |   |--- feature_25 <= 3.48
# |   |   |   |   |   |--- feature_23 <= 1.66
# |   |   |   |   |   |   |--- feature_23 <= 0.97
# |   |   |   |   |   |   |   |--- feature_17 <= 6.11
# |   |   |   |   |   |   |   |   |--- value: [59.94]
# |   |   |   |   |   |   |   |--- feature_17 >  6.11
# |   |   |   |   |   |   |   |   |--- value: [59.44]
# |   |   |   |   |   |   |--- feature_23 >  0.97
# |   |   |   |   |   |   |   |--- feature_30 <= 10.05
# |   |   |   |   |   |   |   |   |--- value: [57.34]
# |   |   |   |   |   |   |   |--- feature_30 >  10.05
# |   |   |   |   |   |   |   |   |--- feature_39 <= 5.55
# |   |   |   |   |   |   |   |   |   |--- value: [55.97]
# |   |   |   |   |   |   |   |   |--- feature_39 >  5.55
# |   |   |   |   |   |   |   |   |   |--- value: [55.80]
# |   |   |   |   |   |--- feature_23 >  1.66
# |   |   |   |   |   |   |--- feature_37 <= 7.58
# |   |   |   |   |   |   |   |--- value: [86.90]
# |   |   |   |   |   |   |--- feature_37 >  7.58
# |   |   |   |   |   |   |   |--- value: [71.02]
# |   |   |   |   |--- feature_25 >  3.48
# |   |   |   |   |   |--- feature_22 <= 22.24
# |   |   |   |   |   |   |--- feature_15 <= 8.24
# |   |   |   |   |   |   |   |--- feature_36 <= 4.97
# |   |   |   |   |   |   |   |   |--- feature_21 <= 15.80
# |   |   |   |   |   |   |   |   |   |--- feature_38 <= 8.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 <= 5.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 >  5.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- feature_38 >  8.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 <= 9.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_38 >  9.24
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_21 >  15.80
# |   |   |   |   |   |   |   |   |   |--- feature_38 <= 7.06
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 14.52
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  14.52
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [33.18]
# |   |   |   |   |   |   |   |   |   |--- feature_38 >  7.06
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 <= 5.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [41.56]
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 >  5.10
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [37.97]
# |   |   |   |   |   |   |   |--- feature_36 >  4.97
# |   |   |   |   |   |   |   |   |--- feature_38 <= 6.33
# |   |   |   |   |   |   |   |   |   |--- feature_33 <= 10.22
# |   |   |   |   |   |   |   |   |   |   |--- value: [41.00]
# |   |   |   |   |   |   |   |   |   |--- feature_33 >  10.22
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 <= 13.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 >  13.38
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_38 >  6.33
# |   |   |   |   |   |   |   |   |   |--- feature_22 <= 12.12
# |   |   |   |   |   |   |   |   |   |   |--- value: [22.78]
# |   |   |   |   |   |   |   |   |   |--- feature_22 >  12.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_28 <= 10.98
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [19.94]
# |   |   |   |   |   |   |   |   |   |   |--- feature_28 >  10.98
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [19.27]
# |   |   |   |   |   |   |--- feature_15 >  8.24
# |   |   |   |   |   |   |   |--- feature_12 <= 16.28
# |   |   |   |   |   |   |   |   |--- feature_18 <= 7.61
# |   |   |   |   |   |   |   |   |   |--- feature_26 <= 10.40
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 <= 11.11
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 >  11.11
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [48.20]
# |   |   |   |   |   |   |   |   |   |--- feature_26 >  10.40
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 <= 7.04
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_7 >  7.04
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [36.80]
# |   |   |   |   |   |   |   |   |--- feature_18 >  7.61
# |   |   |   |   |   |   |   |   |   |--- feature_5 <= 7.90
# |   |   |   |   |   |   |   |   |   |   |--- value: [55.30]
# |   |   |   |   |   |   |   |   |   |--- feature_5 >  7.90
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 <= 11.76
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [59.96]
# |   |   |   |   |   |   |   |   |   |   |--- feature_16 >  11.76
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [59.30]
# |   |   |   |   |   |   |   |--- feature_12 >  16.28
# |   |   |   |   |   |   |   |   |--- value: [96.20]
# |   |   |   |   |   |--- feature_22 >  22.24
# |   |   |   |   |   |   |--- feature_9 <= 12.17
# |   |   |   |   |   |   |   |--- feature_38 <= 5.43
# |   |   |   |   |   |   |   |   |--- feature_24 <= 6.60
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 7.90
# |   |   |   |   |   |   |   |   |   |   |--- value: [88.06]
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  7.90
# |   |   |   |   |   |   |   |   |   |   |--- value: [79.71]
# |   |   |   |   |   |   |   |   |--- feature_24 >  6.60
# |   |   |   |   |   |   |   |   |   |--- feature_24 <= 8.66
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 <= 6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [67.55]
# |   |   |   |   |   |   |   |   |   |   |--- feature_27 >  6.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [68.65]
# |   |   |   |   |   |   |   |   |   |--- feature_24 >  8.66
# |   |   |   |   |   |   |   |   |   |   |--- value: [71.35]
# |   |   |   |   |   |   |   |--- feature_38 >  5.43
# |   |   |   |   |   |   |   |   |--- feature_23 <= 2.05
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= 7.38
# |   |   |   |   |   |   |   |   |   |   |--- value: [47.46]
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  7.38
# |   |   |   |   |   |   |   |   |   |   |--- value: [44.42]
# |   |   |   |   |   |   |   |   |--- feature_23 >  2.05
# |   |   |   |   |   |   |   |   |   |--- feature_32 <= 6.21
# |   |   |   |   |   |   |   |   |   |   |--- value: [54.62]
# |   |   |   |   |   |   |   |   |   |--- feature_32 >  6.21
# |   |   |   |   |   |   |   |   |   |   |--- value: [57.50]
# |   |   |   |   |   |   |--- feature_9 >  12.17
# |   |   |   |   |   |   |   |--- feature_17 <= 7.32
# |   |   |   |   |   |   |   |   |--- feature_16 <= 4.13
# |   |   |   |   |   |   |   |   |   |--- value: [36.81]
# |   |   |   |   |   |   |   |   |--- feature_16 >  4.13
# |   |   |   |   |   |   |   |   |   |--- feature_1 <= 6.12
# |   |   |   |   |   |   |   |   |   |   |--- feature_32 <= 8.77
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [33.57]
# |   |   |   |   |   |   |   |   |   |   |--- feature_32 >  8.77
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [34.34]
# |   |   |   |   |   |   |   |   |   |--- feature_1 >  6.12
# |   |   |   |   |   |   |   |   |   |   |--- value: [32.27]
# |   |   |   |   |   |   |   |--- feature_17 >  7.32
# |   |   |   |   |   |   |   |   |--- feature_11 <= 1.57
# |   |   |   |   |   |   |   |   |   |--- value: [57.68]
# |   |   |   |   |   |   |   |   |--- feature_11 >  1.57
# |   |   |   |   |   |   |   |   |   |--- feature_18 <= 3.61
# |   |   |   |   |   |   |   |   |   |   |--- value: [44.59]
# |   |   |   |   |   |   |   |   |   |--- feature_18 >  3.61
# |   |   |   |   |   |   |   |   |   |   |--- value: [47.73]
# |   |   |   |--- feature_2 >  23.72
# |   |   |   |   |--- feature_1 <= 5.12
# |   |   |   |   |   |--- feature_12 <= 14.09
# |   |   |   |   |   |   |--- value: [100.62]
# |   |   |   |   |   |--- feature_12 >  14.09
# |   |   |   |   |   |   |--- value: [97.53]
# |   |   |   |   |--- feature_1 >  5.12
# |   |   |   |   |   |--- value: [91.16]
# |   |   |--- feature_25 >  17.71
# |   |   |   |--- value: [144.80]
# |   |--- feature_12 >  16.51
# |   |   |--- feature_37 <= 4.55
# |   |   |   |--- value: [195.07]
# |   |   |--- feature_37 >  4.55
# |   |   |   |--- feature_31 <= 5.22
# |   |   |   |   |--- feature_21 <= 12.93
# |   |   |   |   |   |--- value: [181.32]
# |   |   |   |   |--- feature_21 >  12.93
# |   |   |   |   |   |--- feature_13 <= 3.02
# |   |   |   |   |   |   |--- value: [101.59]
# |   |   |   |   |   |--- feature_13 >  3.02
# |   |   |   |   |   |   |--- value: [80.10]
# |   |   |   |--- feature_31 >  5.22
# |   |   |   |   |--- feature_26 <= 6.38
# |   |   |   |   |   |--- value: [156.64]
# |   |   |   |   |--- feature_26 >  6.38
# |   |   |   |   |   |--- feature_12 <= 17.34
# |   |   |   |   |   |   |--- feature_24 <= 22.88
# |   |   |   |   |   |   |   |--- feature_23 <= 1.00
# |   |   |   |   |   |   |   |   |--- feature_25 <= 5.37
# |   |   |   |   |   |   |   |   |   |--- value: [147.03]
# |   |   |   |   |   |   |   |   |--- feature_25 >  5.37
# |   |   |   |   |   |   |   |   |   |--- value: [118.86]
# |   |   |   |   |   |   |   |--- feature_23 >  1.00
# |   |   |   |   |   |   |   |   |--- feature_15 <= 9.18
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 17.13
# |   |   |   |   |   |   |   |   |   |   |--- feature_20 <= 5.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_20 >  5.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  17.13
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 <= 8.75
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 >  8.75
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [53.72]
# |   |   |   |   |   |   |   |   |--- feature_15 >  9.18
# |   |   |   |   |   |   |   |   |   |--- feature_21 <= 9.35
# |   |   |   |   |   |   |   |   |   |   |--- value: [66.08]
# |   |   |   |   |   |   |   |   |   |--- feature_21 >  9.35
# |   |   |   |   |   |   |   |   |   |   |--- feature_22 <= 15.64
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_22 >  15.64
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [48.08]
# |   |   |   |   |   |   |--- feature_24 >  22.88
# |   |   |   |   |   |   |   |--- value: [243.03]
# |   |   |   |   |   |--- feature_12 >  17.34
# |   |   |   |   |   |   |--- feature_40 <= 4.62
# |   |   |   |   |   |   |   |--- feature_5 <= 2.47
# |   |   |   |   |   |   |   |   |--- feature_39 <= 2.80
# |   |   |   |   |   |   |   |   |   |--- feature_22 <= 25.49
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 <= 5.74
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [34.63]
# |   |   |   |   |   |   |   |   |   |   |--- feature_25 >  5.74
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [25.74]
# |   |   |   |   |   |   |   |   |   |--- feature_22 >  25.49
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 <= 2.38
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [56.90]
# |   |   |   |   |   |   |   |   |   |   |--- feature_11 >  2.38
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [50.32]
# |   |   |   |   |   |   |   |   |--- feature_39 >  2.80
# |   |   |   |   |   |   |   |   |   |--- feature_30 <= 16.20
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 <= 3.12
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [46.16]
# |   |   |   |   |   |   |   |   |   |   |--- feature_13 >  3.12
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [55.71]
# |   |   |   |   |   |   |   |   |   |--- feature_30 >  16.20
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 <= 3.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 >  3.93
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |--- feature_5 >  2.47
# |   |   |   |   |   |   |   |   |--- feature_32 <= 19.79
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= 6.44
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 <= 5.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [40.40]
# |   |   |   |   |   |   |   |   |   |   |--- feature_10 >  5.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 5
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  6.44
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 13.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  13.39
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 10
# |   |   |   |   |   |   |   |   |--- feature_32 >  19.79
# |   |   |   |   |   |   |   |   |   |--- value: [138.02]
# |   |   |   |   |   |   |--- feature_40 >  4.62
# |   |   |   |   |   |   |   |--- feature_9 <= 26.40
# |   |   |   |   |   |   |   |   |--- feature_12 <= 22.45
# |   |   |   |   |   |   |   |   |   |--- feature_9 <= 19.95
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 14.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 9
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  14.02
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |   |   |--- feature_9 >  19.95
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 <= 18.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_21 >  18.67
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- feature_12 >  22.45
# |   |   |   |   |   |   |   |   |   |--- feature_3 <= 16.86
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 <= 16.22
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 6
# |   |   |   |   |   |   |   |   |   |   |--- feature_3 >  16.22
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [159.66]
# |   |   |   |   |   |   |   |   |   |--- feature_3 >  16.86
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 <= 2.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_36 >  2.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 12
# |   |   |   |   |   |   |   |--- feature_9 >  26.40
# |   |   |   |   |   |   |   |   |--- feature_11 <= 19.60
# |   |   |   |   |   |   |   |   |   |--- feature_18 <= 4.25
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 <= 21.69
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [56.61]
# |   |   |   |   |   |   |   |   |   |   |--- feature_30 >  21.69
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_18 >  4.25
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 <= 10.99
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [89.38]
# |   |   |   |   |   |   |   |   |   |   |--- feature_14 >  10.99
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_11 >  19.60
# |   |   |   |   |   |   |   |   |   |--- value: [144.42]
# |--- feature_12 >  29.19
# |   |--- feature_37 <= 6.51
# |   |   |--- feature_11 <= 3.20
# |   |   |   |--- value: [200.77]
# |   |   |--- feature_11 >  3.20
# |   |   |   |--- feature_33 <= 17.64
# |   |   |   |   |--- value: [139.61]
# |   |   |   |--- feature_33 >  17.64
# |   |   |   |   |--- value: [130.14]
# |   |--- feature_37 >  6.51
# |   |   |--- feature_29 <= 25.88
# |   |   |   |--- feature_13 <= 12.68
# |   |   |   |   |--- feature_17 <= 21.72
# |   |   |   |   |   |--- feature_10 <= 5.73
# |   |   |   |   |   |   |--- feature_1 <= 15.61
# |   |   |   |   |   |   |   |--- feature_22 <= 15.74
# |   |   |   |   |   |   |   |   |--- feature_37 <= 17.16
# |   |   |   |   |   |   |   |   |   |--- value: [121.38]
# |   |   |   |   |   |   |   |   |--- feature_37 >  17.16
# |   |   |   |   |   |   |   |   |   |--- value: [131.69]
# |   |   |   |   |   |   |   |--- feature_22 >  15.74
# |   |   |   |   |   |   |   |   |--- value: [105.98]
# |   |   |   |   |   |   |--- feature_1 >  15.61
# |   |   |   |   |   |   |   |--- value: [174.58]
# |   |   |   |   |   |--- feature_10 >  5.73
# |   |   |   |   |   |   |--- feature_16 <= 7.31
# |   |   |   |   |   |   |   |--- feature_37 <= 8.95
# |   |   |   |   |   |   |   |   |--- feature_36 <= 11.63
# |   |   |   |   |   |   |   |   |   |--- feature_10 <= 7.86
# |   |   |   |   |   |   |   |   |   |   |--- value: [96.28]
# |   |   |   |   |   |   |   |   |   |--- feature_10 >  7.86
# |   |   |   |   |   |   |   |   |   |   |--- value: [90.52]
# |   |   |   |   |   |   |   |   |--- feature_36 >  11.63
# |   |   |   |   |   |   |   |   |   |--- value: [67.77]
# |   |   |   |   |   |   |   |--- feature_37 >  8.95
# |   |   |   |   |   |   |   |   |--- feature_32 <= 9.85
# |   |   |   |   |   |   |   |   |   |--- feature_23 <= 2.02
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 <= 13.75
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [114.00]
# |   |   |   |   |   |   |   |   |   |   |--- feature_2 >  13.75
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [113.89]
# |   |   |   |   |   |   |   |   |   |--- feature_23 >  2.02
# |   |   |   |   |   |   |   |   |   |   |--- feature_35 <= 10.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [107.71]
# |   |   |   |   |   |   |   |   |   |   |--- feature_35 >  10.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [107.00]
# |   |   |   |   |   |   |   |   |--- feature_32 >  9.85
# |   |   |   |   |   |   |   |   |   |--- feature_6 <= 10.84
# |   |   |   |   |   |   |   |   |   |   |--- value: [123.14]
# |   |   |   |   |   |   |   |   |   |--- feature_6 >  10.84
# |   |   |   |   |   |   |   |   |   |   |--- value: [120.21]
# |   |   |   |   |   |   |--- feature_16 >  7.31
# |   |   |   |   |   |   |   |--- feature_32 <= 6.69
# |   |   |   |   |   |   |   |   |--- feature_28 <= 13.88
# |   |   |   |   |   |   |   |   |   |--- value: [96.48]
# |   |   |   |   |   |   |   |   |--- feature_28 >  13.88
# |   |   |   |   |   |   |   |   |   |--- value: [131.09]
# |   |   |   |   |   |   |   |--- feature_32 >  6.69
# |   |   |   |   |   |   |   |   |--- feature_11 <= 7.27
# |   |   |   |   |   |   |   |   |   |--- feature_12 <= 31.95
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 <= 8.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_39 >  8.01
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |--- feature_12 >  31.95
# |   |   |   |   |   |   |   |   |   |   |--- feature_29 <= 7.63
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- feature_29 >  7.63
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [40.97]
# |   |   |   |   |   |   |   |   |--- feature_11 >  7.27
# |   |   |   |   |   |   |   |   |   |--- feature_16 <= 17.24
# |   |   |   |   |   |   |   |   |   |   |--- value: [106.53]
# |   |   |   |   |   |   |   |   |   |--- feature_16 >  17.24
# |   |   |   |   |   |   |   |   |   |   |--- value: [93.72]
# |   |   |   |   |--- feature_17 >  21.72
# |   |   |   |   |   |--- feature_5 <= 5.64
# |   |   |   |   |   |   |--- feature_7 <= 3.74
# |   |   |   |   |   |   |   |--- feature_20 <= 11.33
# |   |   |   |   |   |   |   |   |--- value: [68.22]
# |   |   |   |   |   |   |   |--- feature_20 >  11.33
# |   |   |   |   |   |   |   |   |--- value: [60.45]
# |   |   |   |   |   |   |--- feature_7 >  3.74
# |   |   |   |   |   |   |   |--- feature_37 <= 10.76
# |   |   |   |   |   |   |   |   |--- feature_14 <= 9.98
# |   |   |   |   |   |   |   |   |   |--- value: [51.41]
# |   |   |   |   |   |   |   |   |--- feature_14 >  9.98
# |   |   |   |   |   |   |   |   |   |--- value: [51.91]
# |   |   |   |   |   |   |   |--- feature_37 >  10.76
# |   |   |   |   |   |   |   |   |--- feature_13 <= 7.22
# |   |   |   |   |   |   |   |   |   |--- value: [36.18]
# |   |   |   |   |   |   |   |   |--- feature_13 >  7.22
# |   |   |   |   |   |   |   |   |   |--- feature_32 <= 22.43
# |   |   |   |   |   |   |   |   |   |   |--- value: [42.08]
# |   |   |   |   |   |   |   |   |   |--- feature_32 >  22.43
# |   |   |   |   |   |   |   |   |   |   |--- value: [42.12]
# |   |   |   |   |   |--- feature_5 >  5.64
# |   |   |   |   |   |   |--- feature_40 <= 9.51
# |   |   |   |   |   |   |   |--- feature_40 <= 9.09
# |   |   |   |   |   |   |   |   |--- feature_2 <= 31.50
# |   |   |   |   |   |   |   |   |   |--- value: [89.97]
# |   |   |   |   |   |   |   |   |--- feature_2 >  31.50
# |   |   |   |   |   |   |   |   |   |--- value: [86.37]
# |   |   |   |   |   |   |   |--- feature_40 >  9.09
# |   |   |   |   |   |   |   |   |--- value: [114.38]
# |   |   |   |   |   |   |--- feature_40 >  9.51
# |   |   |   |   |   |   |   |--- feature_25 <= 32.37
# |   |   |   |   |   |   |   |   |--- feature_23 <= 10.80
# |   |   |   |   |   |   |   |   |   |--- feature_15 <= 26.47
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 <= 32.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_12 >  32.40
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- feature_15 >  26.47
# |   |   |   |   |   |   |   |   |   |   |--- feature_24 <= 16.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- feature_24 >  16.30
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |--- feature_23 >  10.80
# |   |   |   |   |   |   |   |   |   |--- feature_18 <= 4.64
# |   |   |   |   |   |   |   |   |   |   |--- value: [72.03]
# |   |   |   |   |   |   |   |   |   |--- feature_18 >  4.64
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 <= 24.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- feature_19 >  24.34
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- feature_25 >  32.37
# |   |   |   |   |   |   |   |   |--- feature_7 <= 10.99
# |   |   |   |   |   |   |   |   |   |--- value: [108.89]
# |   |   |   |   |   |   |   |   |--- feature_7 >  10.99
# |   |   |   |   |   |   |   |   |   |--- value: [86.35]
# |   |   |   |--- feature_13 >  12.68
# |   |   |   |   |--- feature_18 <= 6.36
# |   |   |   |   |   |--- feature_3 <= 26.69
# |   |   |   |   |   |   |--- feature_14 <= 13.14
# |   |   |   |   |   |   |   |--- feature_28 <= 19.89
# |   |   |   |   |   |   |   |   |--- value: [138.47]
# |   |   |   |   |   |   |   |--- feature_28 >  19.89
# |   |   |   |   |   |   |   |   |--- value: [145.46]
# |   |   |   |   |   |   |--- feature_14 >  13.14
# |   |   |   |   |   |   |   |--- feature_8 <= 20.46
# |   |   |   |   |   |   |   |   |--- value: [162.34]
# |   |   |   |   |   |   |   |--- feature_8 >  20.46
# |   |   |   |   |   |   |   |   |--- value: [154.97]
# |   |   |   |   |   |--- feature_3 >  26.69
# |   |   |   |   |   |   |--- feature_32 <= 27.53
# |   |   |   |   |   |   |   |--- feature_35 <= 15.29
# |   |   |   |   |   |   |   |   |--- value: [95.03]
# |   |   |   |   |   |   |   |--- feature_35 >  15.29
# |   |   |   |   |   |   |   |   |--- value: [90.24]
# |   |   |   |   |   |   |--- feature_32 >  27.53
# |   |   |   |   |   |   |   |--- feature_27 <= 16.86
# |   |   |   |   |   |   |   |   |--- value: [99.22]
# |   |   |   |   |   |   |   |--- feature_27 >  16.86
# |   |   |   |   |   |   |   |   |--- value: [102.43]
# |   |   |   |   |--- feature_18 >  6.36
# |   |   |   |   |   |--- feature_18 <= 15.92
# |   |   |   |   |   |   |--- feature_22 <= 21.55
# |   |   |   |   |   |   |   |--- feature_15 <= 39.53
# |   |   |   |   |   |   |   |   |--- feature_30 <= 11.66
# |   |   |   |   |   |   |   |   |   |--- value: [56.40]
# |   |   |   |   |   |   |   |   |--- feature_30 >  11.66
# |   |   |   |   |   |   |   |   |   |--- value: [50.59]
# |   |   |   |   |   |   |   |--- feature_15 >  39.53
# |   |   |   |   |   |   |   |   |--- value: [44.62]
# |   |   |   |   |   |   |--- feature_22 >  21.55
# |   |   |   |   |   |   |   |--- feature_12 <= 32.73
# |   |   |   |   |   |   |   |   |--- feature_5 <= 7.14
# |   |   |   |   |   |   |   |   |   |--- value: [89.80]
# |   |   |   |   |   |   |   |   |--- feature_5 >  7.14
# |   |   |   |   |   |   |   |   |   |--- value: [93.18]
# |   |   |   |   |   |   |   |--- feature_12 >  32.73
# |   |   |   |   |   |   |   |   |--- feature_25 <= 28.47
# |   |   |   |   |   |   |   |   |   |--- value: [78.44]
# |   |   |   |   |   |   |   |   |--- feature_25 >  28.47
# |   |   |   |   |   |   |   |   |   |--- value: [85.35]
# |   |   |   |   |   |--- feature_18 >  15.92
# |   |   |   |   |   |   |--- feature_18 <= 21.28
# |   |   |   |   |   |   |   |--- feature_11 <= 21.23
# |   |   |   |   |   |   |   |   |--- feature_37 <= 15.04
# |   |   |   |   |   |   |   |   |   |--- value: [98.39]
# |   |   |   |   |   |   |   |   |--- feature_37 >  15.04
# |   |   |   |   |   |   |   |   |   |--- feature_35 <= 11.89
# |   |   |   |   |   |   |   |   |   |   |--- value: [102.00]
# |   |   |   |   |   |   |   |   |   |--- feature_35 >  11.89
# |   |   |   |   |   |   |   |   |   |   |--- value: [102.04]
# |   |   |   |   |   |   |   |--- feature_11 >  21.23
# |   |   |   |   |   |   |   |   |--- value: [86.59]
# |   |   |   |   |   |   |--- feature_18 >  21.28
# |   |   |   |   |   |   |   |--- feature_24 <= 13.29
# |   |   |   |   |   |   |   |   |--- value: [114.58]
# |   |   |   |   |   |   |   |--- feature_24 >  13.29
# |   |   |   |   |   |   |   |   |--- value: [112.77]
# |   |   |--- feature_29 >  25.88
# |   |   |   |--- feature_36 <= 9.16
# |   |   |   |   |--- value: [160.68]
# |   |   |   |--- feature_36 >  9.16
# |   |   |   |   |--- feature_13 <= 4.59
# |   |   |   |   |   |--- value: [137.81]
# |   |   |   |   |--- feature_13 >  4.59
# |   |   |   |   |   |--- value: [124.47]

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(regr, filled=True)
